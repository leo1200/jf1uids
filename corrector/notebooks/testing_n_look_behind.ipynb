# %%
#checking if n_look_behind works at all

import numpy as np
import matplotlib.pyplot as plt

# %%
folders = [
    "/export/home/jalegria/Thesis/jf1uids/experiments/experiment_1/2025-09-29_13-15-45_5",
    "/export/home/jalegria/Thesis/jf1uids/experiments/experiment_1/2025-09-29_13-16-19_10"
]

# %%
n_1_1 = np.load("/export/home/jalegria/Thesis/jf1uids/experiments/n_look_behind_works/2025-09-24_17-20-57_1/losses.npz", allow_pickle=True)
n_1_2 = np.load("/export/home/jalegria/Thesis/jf1uids/experiments/n_look_behind_works/2025-09-24_17-20-21_1/losses.npz", allow_pickle=True)

n_10 = np.load("/export/home/jalegria/Thesis/jf1uids/experiments/n_look_behind_works/2025-09-24_17-21-19_10/losses.npz", allow_pickle=True)

# %%
n_1_1.files
# Out:
# ['n_look_behind', 'epoch_losses', 'snapshot_losses']

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(n_1_1['snapshot_losses'][:10], label = "1_1")
ax.plot(n_1_2['snapshot_losses'][:10], label = "1_2")
ax.plot(n_10['snapshot_losses'][:10], label = "10")
ax.legend()
