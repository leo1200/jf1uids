# %% [markdown]
# # Gradient Descent for Finding Stellar Wind Parameters

# %% [markdown]
# ## Imports

# %%
# numerics
import jax
import jax.numpy as jnp
import numpy as np
from alive_progress import alive_bar
import optax

# timing
from timeit import default_timer as timer

# plotting
import matplotlib.pyplot as plt

# fluids
from jf1uids.boundaries import OPEN_BOUNDARY, REFLECTIVE_BOUNDARY
from jf1uids.geometry import SPHERICAL
from jf1uids.physics_modules.stellar_wind import WindParams
from jf1uids.postprocessing import shock_sensor, strongest_shock_radius
from jf1uids.simulation_config import SimulationConfig
from jf1uids.simulation_helper_data import get_helper_data
from jf1uids.simulation_params import SimulationParams
from jf1uids.time_integration import time_integration
from jf1uids.fluid import primitive_state

# units
from jf1uids.unit_helpers import CodeUnits
from astropy import units as u
import astropy.constants as c
from astropy.constants import m_p

# wind-specific
from weaver import Weaver
from jax import grad

# # for now using CPU as of outdated NVIDIA Driver
jax.config.update('jax_platform_name', 'cpu')

# # 64-bit precision
jax.config.update("jax_enable_x64", True)

# %% [markdown]
# ## Initiating the stellar wind simulation

# %%
print("👷 Setting up simulation...")

# simulation settings
gamma = 5/3

# spatial domain
alpha = SPHERICAL
box_size = 1.0
num_cells = 600
dx = box_size / num_cells

fixed_timestep = True
num_timesteps = 25000

# introduce constants to 
# make this more readable
left_boundary = REFLECTIVE_BOUNDARY
right_boundary = OPEN_BOUNDARY

# activate stellar wind
stellar_wind = True

# setup simulation config
config = SimulationConfig(
    alpha_geom = alpha,
    box_size = box_size, 
    num_cells = num_cells,
    left_boundary = left_boundary, 
    right_boundary = right_boundary, 
    stellar_wind = stellar_wind,
    fixed_timestep = fixed_timestep,
    num_timesteps = num_timesteps
)

helper_data = get_helper_data(config)
# Out:
# 👷 Setting up simulation...

# %% [markdown]
# ## Setting the simulation parameters and initial state

# %%
# code units
code_length = 3 * u.parsec
code_mass = 1e-4 * u.M_sun
code_velocity = 1 * u.km / u.s
code_units = CodeUnits(code_length, code_mass, code_velocity)

# time domain
C_CFL = 0.8
t_final = 2.5 * 1e4 * u.yr
t_end = t_final.to(code_units.code_time).value
dt_max = 0.0001 * t_end

params = SimulationParams(
    C_cfl = C_CFL,
    dt_max = dt_max,
    dx = dx,
    gamma = gamma,
    t_end = t_end
)

# homogeneous initial state
rho_0 = 2 * c.m_p / u.cm**3
p_0 = 3e4 * u.K / u.cm**3 * c.k_B

rho_init = jnp.ones(num_cells) * rho_0.to(code_units.code_density).value
u_init = jnp.zeros(num_cells)
p_init = jnp.ones(num_cells) * p_0.to(code_units.code_pressure).value

# get initial state
initial_state = primitive_state(rho_init, u_init, p_init)

# %% [markdown]
# ## Setting up a reference simulation

# %%
from jf1uids.postprocessing import strongest_shock_dissipated_energy_flux


sample_simulation = lambda velocity, mass_loss_rate: time_integration(initial_state, config, SimulationParams(
    C_cfl=params.C_cfl,
    dt_max=params.dt_max,
    dx=params.dx,
    gamma=params.gamma,
    t_end=params.t_end,
    wind_params=WindParams(
        wind_mass_loss_rate=mass_loss_rate,
        wind_final_velocity=velocity
    )
), helper_data)

# generate a reference simulation
# M_star = 32.82 * u.M_sun
# wind_final_velocity = 2212.7 * u.km / u.s
# wind_mass_loss_rate = 2.965e-3 / (1e6 * u.yr) * M_star

M_star = 15 * u.M_sun
wind_final_velocity = 3000 * u.km / u.s
wind_mass_loss_rate = 2.965e-3 / (1e6 * u.yr) * M_star

reference_params = WindParams(
    wind_mass_loss_rate = wind_mass_loss_rate.to(code_units.code_mass / code_units.code_time).value,
    wind_final_velocity = wind_final_velocity.to(code_units.code_velocity).value
)

reference_simulation = sample_simulation(
    reference_params.wind_final_velocity,
    reference_params.wind_mass_loss_rate
)

def two_strongest_shock_radii(primitive_state, helper_data, padL, padR, cutout):
    r = helper_data.geometric_centers[padL + 1: -padR - 1]
    shock_sensors = shock_sensor(primitive_state)[padL: -padR]
    max_shock_idx_A = jnp.argmax(shock_sensors)

    max_shock_idx_B_right = jnp.argmax(shock_sensors[max_shock_idx_A + cutout:]) + max_shock_idx_A + cutout

    max_shock_idx_B_left = jnp.argmax(shock_sensors[:jnp.maximum(1,max_shock_idx_A - cutout)])

    val_left = shock_sensors[max_shock_idx_B_left]
    val_right = shock_sensors[max_shock_idx_B_right]

    vals = jnp.array([val_left, val_right])
    idxs = jnp.array([max_shock_idx_B_left, max_shock_idx_B_right])
    max_shock_idx_B = idxs[jnp.argmax(vals)]

    rA = (r[max_shock_idx_A - 1] * shock_sensors[max_shock_idx_A - 1] + r[max_shock_idx_A] * shock_sensors[max_shock_idx_A] + r[max_shock_idx_A + 1] * shock_sensors[max_shock_idx_A + 1]) / (shock_sensors[max_shock_idx_A - 1] + shock_sensors[max_shock_idx_A] + shock_sensors[max_shock_idx_A + 1])
    rB = (r[max_shock_idx_B - 1] * shock_sensors[max_shock_idx_B - 1] + r[max_shock_idx_B] * shock_sensors[max_shock_idx_B] + r[max_shock_idx_B + 1] * shock_sensors[max_shock_idx_B + 1]) / (shock_sensors[max_shock_idx_B - 1] + shock_sensors[max_shock_idx_B] + shock_sensors[max_shock_idx_B + 1])

    shock_radii = jnp.array([rA, rB])
    # sort the radii
    rA, rB = jnp.sort(shock_radii)
    return rA, rB

# get the strongest shock radius
reference_inner_shock_radius, reference_outer_shock_radius = two_strongest_shock_radii(reference_simulation, helper_data, 50, 10, 5)

plt.semilogy(helper_data.geometric_centers, reference_simulation[0])
plt.axvline(x=reference_outer_shock_radius, color='r')
plt.axvline(x=reference_inner_shock_radius, color='g')

print(reference_inner_shock_radius, reference_outer_shock_radius)


# 0.14081862855996063 0.7102643057323199
# 0.14794231003681693 0.7094265786264813
# Out:
# 0.11420369272158154 0.6871065446090175

# %% [markdown]
# ## Losses

# %%
def density_loss(vel_mass_loss):
    velocity = vel_mass_loss[0]
    mass_loss_rate = vel_mass_loss[1]
    final_state = sample_simulation(velocity, mass_loss_rate)
    return jnp.mean(jnp.abs(final_state[0] - reference_simulation[0]))

def full_profile_loss(vel_mass_loss):
    velocity = vel_mass_loss[0]
    mass_loss_rate = vel_mass_loss[1]
    final_state = sample_simulation(velocity, mass_loss_rate)
    return jnp.sum(jnp.abs(final_state - reference_simulation))

def shock_radius_loss(vel_mass_loss):
    velocity = vel_mass_loss[0]
    mass_loss_rate = vel_mass_loss[1]
    final_state = sample_simulation(velocity, mass_loss_rate)
    inner_shock_radius, outer_shock_radius = two_strongest_shock_radii(final_state, helper_data, 50, 10, 5)
    return jnp.abs(outer_shock_radius - reference_outer_shock_radius) + jnp.abs(inner_shock_radius - reference_inner_shock_radius)

loss = shock_radius_loss

# %% [markdown]
# ## Loss map

# %%
def get_loss_map(velocity_range, mass_loss_rate_range):
    print("🔍 Generating loss map...")
    loss_map = jnp.zeros((len(velocity_range) * len(mass_loss_rate_range),))
    vel_list = jnp.zeros((len(velocity_range) * len(mass_loss_rate_range),))
    mass_list = jnp.zeros((len(velocity_range) * len(mass_loss_rate_range),))
    ind = 0
    with alive_bar(len(velocity_range) * len(mass_loss_rate_range)) as bar:
        for i, velocity in enumerate(velocity_range):
            for j, mass_loss_rate in enumerate(mass_loss_rate_range):
                loss_map = loss_map.at[ind].set(loss((velocity, mass_loss_rate)))
                vel_list = vel_list.at[ind].set(velocity)
                mass_list = mass_list.at[ind].set(mass_loss_rate)
                ind += 1
                bar()
        return loss_map, vel_list, mass_list

# generate a loss map
mass_loss_rates = jnp.linspace(
    (2.965e-3 / (1e6 * u.yr) * 15 * u.M_sun).to(code_units.code_mass / code_units.code_time).value,
    (2.965e-3 / (1e6 * u.yr) * 70 * u.M_sun).to(code_units.code_mass / code_units.code_time).value,
    20
)

velocities = jnp.linspace(
    (200 * u.km / u.s).to(code_units.code_velocity).value,
    (3000 * u.km / u.s).to(code_units.code_velocity).value,
    20
)

loss_map, vel_list, mass_list = get_loss_map(velocities, mass_loss_rates)
# Out:
# 🔍 Generating loss map...
# |████████████████████████████████████████| 400/400 [100%] in 8:29.1 (0.79/s)

# %% [markdown]
# ## Optimization

# %%
# def newton_optimization(func, x_init, tol=1e-6, max_iter=1000):
#     x = x_init
#     for _ in range(max_iter):
#         # Compute the function value and its gradient
#         f_grad = jax.grad(func)(x)
        
#         # Compute the Hessian matrix
#         f_hessian = jax.hessian(func)(x)
        
#         # Compute the Newton update step
#         delta_x = jnp.linalg.solve(f_hessian, -f_grad)
        
#         # Update the parameter
#         x += delta_x

#         print(f"Optimal wind final velocity: {(x[0] * code_units.code_velocity).to(u.km / u.s)}")
#         print(f"Optimal wind mass loss rate: {(x[1] * code_units.code_mass / code_units.code_time).to(2.965e-3 / (1e6 * u.yr) * u.M_sun)}")

        
#         # Check convergence
#         if jnp.linalg.norm(delta_x) < tol:
#             break
    
#     return x

# also implement gradient descent
def gradient_descent_optimization(func, x_init, learning_rate=20, tol=0.5, max_iter=2000):
    xlist = []
    x = x_init
    loss_list = []
    xlist.append(x)
    print(f"Optimal wind final velocity: {x[0]}")
    print(f"Optimal wind mass loss rate: {x[1]}")

    optimizer = optax.adam(learning_rate=learning_rate)
    optimizer_state = optimizer.init(x)

    for _ in range(max_iter):
        # Compute the function value and its gradient
        loss, f_grad = jax.value_and_grad(func)(x)
        loss_list.append(loss)
        
        # Update the parameter
        updates, optimizer_state = optimizer.update(f_grad, optimizer_state)
        x = optax.apply_updates(x, updates)
        xlist.append(x)

        print(f"Optimal wind final velocity: {(x[0] * code_units.code_velocity).to(u.km / u.s)}")
        print(f"Optimal wind mass loss rate: {(x[1] * code_units.code_mass / code_units.code_time).to(2.965e-3 / (1e6 * u.yr) * u.M_sun)}")

        # Check convergence
        if jnp.linalg.norm(updates) < tol:
            break
    
    return x, xlist, loss_list

def random_wind_initialization(v_min, v_max, m_min, m_max):
    # pick a random velocity and mass loss rate between the given ranges
    velocity = np.random.uniform(v_min, v_max)
    mass_loss_rate = np.random.uniform(m_min, m_max)
    return jnp.array([velocity, mass_loss_rate])

# get a random initial guess
initial_guess = random_wind_initialization(
    (200 * u.km / u.s).to(code_units.code_velocity).value,
    (4000 * u.km / u.s).to(code_units.code_velocity).value,
    (2.965e-3 / (1e6 * u.yr) * 15 * u.M_sun).to(code_units.code_mass / code_units.code_time).value,
    (2.965e-3 / (1e6 * u.yr) * 70 * u.M_sun).to(code_units.code_mass / code_units.code_time).value
)

# print(initial_guess)


# M_star_optim = 30 * u.M_sun
# wind_final_velocity_optim = (1500 * u.km / u.s).to(code_units.code_velocity).value
# wind_mass_loss_rate_optim = (2.965e-3 / (1e6 * u.yr) * M_star_optim).to(code_units.code_mass / code_units.code_time).value

# vel_mass_loss_optim = jnp.array([wind_final_velocity_optim, wind_mass_loss_rate_optim])

# optimize the mass loss rate and final velocity using gradient descent
# optimized_params = gradient_descent_optimization(density_loss, vel_mass_loss_optim)

# %% [markdown]
# ## Example loss paths

# %%
# random initialization 1
# initial_guess = random_wind_initialization(
#     (1000 * u.km / u.s).to(code_units.code_velocity).value,
#     (3500 * u.km / u.s).to(code_units.code_velocity).value,
#     (2.965e-3 / (1e6 * u.yr) * 10 * u.M_sun).to(code_units.code_mass / code_units.code_time).value,
#     (2.965e-3 / (1e6 * u.yr) * 70 * u.M_sun).to(code_units.code_mass / code_units.code_time).value
# )
initial_guess1 = jnp.array([(1500 * u.km / u.s).to(code_units.code_velocity).value, (2.965e-3 / (1e6 * u.yr) * 30 * u.M_sun).to(code_units.code_mass / code_units.code_time).value])
x1, xlist1, loss_list1 = gradient_descent_optimization(loss, initial_guess1)

# random initialization 2
# initial_guess = random_wind_initialization(
#     (1000 * u.km / u.s).to(code_units.code_velocity).value,
#     (3500 * u.km / u.s).to(code_units.code_velocity).value,
#     (2.965e-3 / (1e6 * u.yr) * 10 * u.M_sun).to(code_units.code_mass / code_units.code_time).value,
#     (2.965e-3 / (1e6 * u.yr) * 70 * u.M_sun).to(code_units.code_mass / code_units.code_time).value
# )
initial_guess2 = jnp.array([(2500 * u.km / u.s).to(code_units.code_velocity).value, (2.965e-3 / (1e6 * u.yr) * 60 * u.M_sun).to(code_units.code_mass / code_units.code_time).value])
x2, xlist2, loss_list2 = gradient_descent_optimization(loss, initial_guess2)

# random initialization 3
# initial_guess = random_wind_initialization(
#     (1000 * u.km / u.s).to(code_units.code_velocity).value,
#     (3500 * u.km / u.s).to(code_units.code_velocity).value,
#     (2.965e-3 / (1e6 * u.yr) * 10 * u.M_sun).to(code_units.code_mass / code_units.code_time).value,
#     (2.965e-3 / (1e6 * u.yr) * 70 * u.M_sun).to(code_units.code_mass / code_units.code_time).value
# )
initial_guess3 = jnp.array([(200 * u.km / u.s).to(code_units.code_velocity).value, (2.965e-3 / (1e6 * u.yr) * 45 * u.M_sun).to(code_units.code_mass / code_units.code_time).value])
x3, xlist3, loss_list3 = gradient_descent_optimization(loss, initial_guess3)
# Out:
# Optimal wind final velocity: 1500.0
# Optimal wind mass loss rate: 2609.2385435551855
# Optimal wind final velocity: 1519.9979607212406 km / s
# Optimal wind mass loss rate: 30.229823884233266 2.965e-09 solMass / yr
# Optimal wind final velocity: 1540.0192507260922 km / s
# Optimal wind mass loss rate: 30.459756663817952 2.965e-09 solMass / yr
# Optimal wind final velocity: 1560.0428364773936 km / s
# Optimal wind mass loss rate: 30.689904511706185 2.965e-09 solMass / yr
# Optimal wind final velocity: 1579.910873548489 km / s
# Optimal wind mass loss rate: 30.91712395748313 2.965e-09 solMass / yr
# Optimal wind final velocity: 1599.8695609267586 km / s
# Optimal wind mass loss rate: 31.145475127807742 2.965e-09 solMass / yr
# Optimal wind final velocity: 1619.859339859966 km / s
# Optimal wind mass loss rate: 31.375081820724905 2.965e-09 solMass / yr
# Optimal wind final velocity: 1639.7131420467715 km / s
# Optimal wind mass loss rate: 31.602090375920792 2.965e-09 solMass / yr
# Optimal wind final velocity: 1659.6333758740923 km / s
# Optimal wind mass loss rate: 31.830350601346456 2.965e-09 solMass / yr
# Optimal wind final velocity: 1679.6120128709472 km / s
# Optimal wind mass loss rate: 32.060105493955895 2.965e-09 solMass / yr
# Optimal wind final velocity: 1699.5042318970234 km / s
# Optimal wind mass loss rate: 32.287828654903144 2.965e-09 solMass / yr
# Optimal wind final velocity: 1719.3563981418927 km / s
# Optimal wind mass loss rate: 32.51570346087124 2.965e-09 solMass / yr
# Optimal wind final velocity: 1739.2700268976996 km / s
# Optimal wind mass loss rate: 32.744196058345345 2.965e-09 solMass / yr
# Optimal wind final velocity: 1759.2187624660985 km / s
# Optimal wind mass loss rate: 32.97421252135473 2.965e-09 solMass / yr
# Optimal wind final velocity: 1779.0878241490493 km / s
# Optimal wind mass loss rate: 33.204279114516545 2.965e-09 solMass / yr
# Optimal wind final velocity: 1798.7399737265832 km / s
# Optimal wind mass loss rate: 33.42980379989932 2.965e-09 solMass / yr
# Optimal wind final velocity: 1818.4592063253413 km / s
# Optimal wind mass loss rate: 33.657754452284806 2.965e-09 solMass / yr
# Optimal wind final velocity: 1838.2686520866666 km / s
# Optimal wind mass loss rate: 33.88761772015898 2.965e-09 solMass / yr
# Optimal wind final velocity: 1858.087677581466 km / s
# Optimal wind mass loss rate: 34.11831674534643 2.965e-09 solMass / yr
# Optimal wind final velocity: 1877.791148735908 km / s
# Optimal wind mass loss rate: 34.345999058413376 2.965e-09 solMass / yr
# Optimal wind final velocity: 1897.332889971194 km / s
# Optimal wind mass loss rate: 34.57177742641077 2.965e-09 solMass / yr
# Optimal wind final velocity: 1916.8614188844763 km / s
# Optimal wind mass loss rate: 34.79900822379442 2.965e-09 solMass / yr
# Optimal wind final velocity: 1936.4313444215663 km / s
# Optimal wind mass loss rate: 35.0269530953835 2.965e-09 solMass / yr
# Optimal wind final velocity: 1956.093994377803 km / s
# Optimal wind mass loss rate: 35.25785399053715 2.965e-09 solMass / yr
# Optimal wind final velocity: 1975.8124882523343 km / s
# Optimal wind mass loss rate: 35.48996576326865 2.965e-09 solMass / yr
# Optimal wind final velocity: 1990.8936324975757 km / s
# Optimal wind mass loss rate: 35.62666934162516 2.965e-09 solMass / yr
# Optimal wind final velocity: 2001.9168999064732 km / s
# Optimal wind mass loss rate: 35.689242599601464 2.965e-09 solMass / yr
# Optimal wind final velocity: 2009.358290661149 km / s
# Optimal wind mass loss rate: 35.693614625952 2.965e-09 solMass / yr
# Optimal wind final velocity: 2013.7949505865838 km / s
# Optimal wind mass loss rate: 35.65299667807677 2.965e-09 solMass / yr
# Optimal wind final velocity: 2015.5574784425082 km / s
# Optimal wind mass loss rate: 35.57549868154403 2.965e-09 solMass / yr
# Optimal wind final velocity: 2015.1442042329415 km / s
# Optimal wind mass loss rate: 35.46996195748151 2.965e-09 solMass / yr
# Optimal wind final velocity: 2012.5675977473416 km / s
# Optimal wind mass loss rate: 35.33734442655045 2.965e-09 solMass / yr
# Optimal wind final velocity: 2007.957034949305 km / s
# Optimal wind mass loss rate: 35.18248182829905 2.965e-09 solMass / yr
# Optimal wind final velocity: 2001.5378268834704 km / s
# Optimal wind mass loss rate: 35.00927879919452 2.965e-09 solMass / yr
# Optimal wind final velocity: 1993.551952486709 km / s
# Optimal wind mass loss rate: 34.820406801609174 2.965e-09 solMass / yr
# Optimal wind final velocity: 1984.1394888553916 km / s
# Optimal wind mass loss rate: 34.61806418554413 2.965e-09 solMass / yr
# Optimal wind final velocity: 1973.4397287960037 km / s
# Optimal wind mass loss rate: 34.40417178287724 2.965e-09 solMass / yr
# Optimal wind final velocity: 1965.442503905489 km / s
# Optimal wind mass loss rate: 34.2220847821837 2.965e-09 solMass / yr
# Optimal wind final velocity: 1959.9558301127872 km / s
# Optimal wind mass loss rate: 34.070904050455766 2.965e-09 solMass / yr
# Optimal wind final velocity: 1956.828098364094 km / s
# Optimal wind mass loss rate: 33.9490920605929 2.965e-09 solMass / yr
# Optimal wind final velocity: 1955.9764913639553 km / s
# Optimal wind mass loss rate: 33.85517664101264 2.965e-09 solMass / yr
# Optimal wind final velocity: 1957.1307428627952 km / s
# Optimal wind mass loss rate: 33.78460425998858 2.965e-09 solMass / yr
# Optimal wind final velocity: 1960.0794183302055 km / s
# Optimal wind mass loss rate: 33.73732158081117 2.965e-09 solMass / yr
# Optimal wind final velocity: 1964.7158877984562 km / s
# Optimal wind mass loss rate: 33.71232434245008 2.965e-09 solMass / yr
# Optimal wind final velocity: 1970.7899163121442 km / s
# Optimal wind mass loss rate: 33.70645967729598 2.965e-09 solMass / yr
# Optimal wind final velocity: 1978.0952831674153 km / s
# Optimal wind mass loss rate: 33.71705882264777 2.965e-09 solMass / yr
# Optimal wind final velocity: 1986.4968935486797 km / s
# Optimal wind mass loss rate: 33.74142745567074 2.965e-09 solMass / yr
# Optimal wind final velocity: 1996.048173805568 km / s
# Optimal wind mass loss rate: 33.78109213702305 2.965e-09 solMass / yr
# Optimal wind final velocity: 2006.6083951218166 km / s
# Optimal wind mass loss rate: 33.83492833838821 2.965e-09 solMass / yr
# Optimal wind final velocity: 2013.8510214698788 km / s
# Optimal wind mass loss rate: 33.84484987440953 2.965e-09 solMass / yr
# Optimal wind final velocity: 2018.374374204291 km / s
# Optimal wind mass loss rate: 33.81936276887563 2.965e-09 solMass / yr
# Optimal wind final velocity: 2020.2825046872213 km / s
# Optimal wind mass loss rate: 33.76072058814025 2.965e-09 solMass / yr
# Optimal wind final velocity: 2019.8324736961822 km / s
# Optimal wind mass loss rate: 33.67307134685202 2.965e-09 solMass / yr
# Optimal wind final velocity: 2017.512857926392 km / s
# Optimal wind mass loss rate: 33.562522218851235 2.965e-09 solMass / yr
# Optimal wind final velocity: 2013.1907500317327 km / s
# Optimal wind mass loss rate: 33.427675561155425 2.965e-09 solMass / yr
# Optimal wind final velocity: 2007.2959625396654 km / s
# Optimal wind mass loss rate: 33.27447638288053 2.965e-09 solMass / yr
# Optimal wind final velocity: 2003.5919210349077 km / s
# Optimal wind mass loss rate: 33.14909210569812 2.965e-09 solMass / yr
# Optimal wind final velocity: 2002.2130123212712 km / s
# Optimal wind mass loss rate: 33.05165638223465 2.965e-09 solMass / yr
# Optimal wind final velocity: 2002.7010448102424 km / s
# Optimal wind mass loss rate: 32.97726292495876 2.965e-09 solMass / yr
# Optimal wind final velocity: 2004.7977557482686 km / s
# Optimal wind mass loss rate: 32.92329487795729 2.965e-09 solMass / yr
# Optimal wind final velocity: 2008.3044276483677 km / s
# Optimal wind mass loss rate: 32.886586552133295 2.965e-09 solMass / yr
# Optimal wind final velocity: 2013.2977974488465 km / s
# Optimal wind mass loss rate: 32.86865446386865 2.965e-09 solMass / yr
# Optimal wind final velocity: 2019.7278788357519 km / s
# Optimal wind mass loss rate: 32.8690141248684 2.965e-09 solMass / yr
# Optimal wind final velocity: 2027.1198724633564 km / s
# Optimal wind mass loss rate: 32.88227489885333 2.965e-09 solMass / yr
# Optimal wind final velocity: 2035.647258108142 km / s
# Optimal wind mass loss rate: 32.910534097698985 2.965e-09 solMass / yr
# Optimal wind final velocity: 2041.036067031141 km / s
# Optimal wind mass loss rate: 32.89665636832664 2.965e-09 solMass / yr
# Optimal wind final velocity: 2043.8120909096851 km / s
# Optimal wind mass loss rate: 32.84820809824491 2.965e-09 solMass / yr
# Optimal wind final velocity: 2044.3112530011635 km / s
# Optimal wind mass loss rate: 32.770319274019144 2.965e-09 solMass / yr
# Optimal wind final velocity: 2042.655752763484 km / s
# Optimal wind mass loss rate: 32.66567708844292 2.965e-09 solMass / yr
# Optimal wind final velocity: 2038.92869674879 km / s
# Optimal wind mass loss rate: 32.53569771890753 2.965e-09 solMass / yr
# Optimal wind final velocity: 2033.4817486170446 km / s
# Optimal wind mass loss rate: 32.385320978403676 2.965e-09 solMass / yr
# Optimal wind final velocity: 2030.2290303169389 km / s
# Optimal wind mass loss rate: 32.26315983751311 2.965e-09 solMass / yr
# Optimal wind final velocity: 2029.2525293300562 km / s
# Optimal wind mass loss rate: 32.16958834192428 2.965e-09 solMass / yr
# Optimal wind final velocity: 2030.075397344394 km / s
# Optimal wind mass loss rate: 32.098011553573535 2.965e-09 solMass / yr
# Optimal wind final velocity: 2032.4515432493065 km / s
# Optimal wind mass loss rate: 32.0460915924199 2.965e-09 solMass / yr
# Optimal wind final velocity: 2036.196946740532 km / s
# Optimal wind mass loss rate: 32.01187406632844 2.965e-09 solMass / yr
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 9
#       1 # random initialization 1
#       2 # initial_guess = random_wind_initialization(
#       3 #     (1000 * u.km / u.s).to(code_units.code_velocity).value,
#    (...)
#       6 #     (2.965e-3 / (1e6 * u.yr) * 70 * u.M_sun).to(code_units.code_mass / code_units.code_time).value
#       7 # )
#       8 initial_guess1 = jnp.array([(1500 * u.km / u.s).to(code_units.code_velocity).value, (2.965e-3 / (1e6 * u.yr) * 30 * u.M_sun).to(code_units.code_mass / code_units.code_time).value])
# ----> 9 x1, xlist1, loss_list1 = gradient_descent_optimization(loss, initial_guess1)
#      11 # random initialization 2
#      12 # initial_guess = random_wind_initialization(
#      13 #     (1000 * u.km / u.s).to(code_units.code_velocity).value,
#    (...)
#      16 #     (2.965e-3 / (1e6 * u.yr) * 70 * u.M_sun).to(code_units.code_mass / code_units.code_time).value
#      17 # )
#      18 initial_guess2 = jnp.array([(2500 * u.km / u.s).to(code_units.code_velocity).value, (2.965e-3 / (1e6 * u.yr) * 60 * u.M_sun).to(code_units.code_mass / code_units.code_time).value])
#
# Cell In[41], line 40, in gradient_descent_optimization(func, x_init, learning_rate, tol, max_iter)
#      36 optimizer_state = optimizer.init(x)
#      38 for _ in range(max_iter):
#      39     # Compute the function value and its gradient
# ---> 40     loss, f_grad = jax.value_and_grad(func)(x)
#      41     loss_list.append(loss)
#      43     # Update the parameter
#
#     [... skipping hidden 1 frame]
#
# File ~/miniforge3/envs/jf1uids/lib/python3.11/site-packages/jax/_src/api.py:701, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     699   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     700 if not has_aux:
# --> 701   ans, vjp_py = _vjp(f_partial, *dyn_args)
#     702 else:
#     703   ans, vjp_py, aux = _vjp(
#     704       f_partial, *dyn_args, has_aux=True)
#
# File ~/miniforge3/envs/jf1uids/lib/python3.11/site-packages/jax/_src/api.py:2195, in _vjp(fun, has_aux, *primals)
#    2193 if not has_aux:
#    2194   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2195   out_primals, vjp = ad.vjp(flat_fun, primals_flat)
#    2196   out_tree = out_tree()
#    2197 else:
#
# File ~/miniforge3/envs/jf1uids/lib/python3.11/site-packages/jax/_src/interpreters/ad.py:143, in vjp(traceable, primals, has_aux)
#     141 def vjp(traceable, primals, has_aux=False):
#     142   if not has_aux:
# --> 143     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     144   else:
#     145     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/miniforge3/envs/jf1uids/lib/python3.11/site-packages/jax/_src/interpreters/ad.py:132, in linearize(traceable, *primals, **kwargs)
#     130 _, in_tree = tree_flatten(((primals, primals), {}))
#     131 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 132 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     133 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     134 assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# File ~/miniforge3/envs/jf1uids/lib/python3.11/site-packages/jax/_src/profiler.py:336, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     333 @wraps(func)
#     334 def wrapper(*args, **kwargs):
#     335   with TraceAnnotation(name, **decorator_kwargs):
# --> 336     return func(*args, **kwargs)
#     337   return wrapper
#
# File ~/miniforge3/envs/jf1uids/lib/python3.11/site-packages/jax/_src/interpreters/partial_eval.py:777, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     775 with core.new_main(JaxprTrace, name_stack=current_name_stack) as main:
#     776   fun = trace_to_subjaxpr_nounits(fun, main, instantiate)
# --> 777   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     778   assert not env
#     779   del main, fun, env
#
# File ~/miniforge3/envs/jf1uids/lib/python3.11/site-packages/jax/_src/linear_util.py:193, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     190 gen = gen_static_args = out_store = None
#     192 try:
# --> 193   ans = self.f(*args, **dict(self.params, **kwargs))
#     194 except:
#     195   # Some transformations yield from inside context managers, so we have to
#     196   # interrupt them before reraising the exception. Otherwise they will only
#     197   # get garbage-collected at some later time, running their cleanup tasks
#     198   # only after this exception is handled, which can corrupt the global
#     199   # state.
#     200   while stack:
#
# Cell In[33], line 16, in shock_radius_loss(vel_mass_loss)
#      14 velocity = vel_mass_loss[0]
#      15 mass_loss_rate = vel_mass_loss[1]
# ---> 16 final_state = sample_simulation(velocity, mass_loss_rate)
#      17 inner_shock_radius, outer_shock_radius = two_strongest_shock_radii(final_state, helper_data, 50, 10, 5)
#      18 return jnp.abs(outer_shock_radius - reference_outer_shock_radius) + jnp.abs(inner_shock_radius - reference_inner_shock_radius)
#
# Cell In[32], line 4, in <lambda>(velocity, mass_loss_rate)
#       1 from jf1uids.postprocessing import strongest_shock_dissipated_energy_flux
# ----> 4 sample_simulation = lambda velocity, mass_loss_rate: time_integration(initial_state, config, SimulationParams(
#       5     C_cfl=params.C_cfl,
#       6     dt_max=params.dt_max,
#       7     dx=params.dx,
#       8     gamma=params.gamma,
#       9     t_end=params.t_end,
#      10     wind_params=WindParams(
#      11         wind_mass_loss_rate=mass_loss_rate,
#      12         wind_final_velocity=velocity
#      13     )
#      14 ), helper_data)
#      16 # generate a reference simulation
#      17 # M_star = 32.82 * u.M_sun
#      18 # wind_final_velocity = 2212.7 * u.km / u.s
#      19 # wind_mass_loss_rate = 2.965e-3 / (1e6 * u.yr) * M_star
#      21 M_star = 15 * u.M_sun
#
#     [... skipping hidden 1 frame]
#
# File ~/miniforge3/envs/jf1uids/lib/python3.11/site-packages/jax/_src/pjit.py:332, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     330 @api_boundary
#     331 def cache_miss(*args, **kwargs):
# --> 332   outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     333       fun, jit_info, *args, **kwargs)
#     334   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     335   pgle_profiler = _read_pgle_profiler(jaxpr)
#
# File ~/miniforge3/envs/jf1uids/lib/python3.11/site-packages/jax/_src/pjit.py:190, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     187   args_flat = [*init_states, *args_flat]
#     189 try:
# --> 190   out_flat = pjit_p.bind(*args_flat, **p.params)
#     191 except pxla.DeviceAssignmentMismatchError as e:
#     192   fails, = e.args
#
# File ~/miniforge3/envs/jf1uids/lib/python3.11/site-packages/jax/_src/core.py:2739, in AxisPrimitive.bind(self, *args, **params)
#    2735 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2736                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2737 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2738              else axis_main.with_cur_sublevel())
# -> 2739 return self.bind_with_trace(top_trace, args, params)
#
# File ~/miniforge3/envs/jf1uids/lib/python3.11/site-packages/jax/_src/core.py:433, in Primitive.bind_with_trace(self, trace, args, params)
#     431 def bind_with_trace(self, trace, args, params):
#     432   with pop_level(trace.level):
# --> 433     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     434   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniforge3/envs/jf1uids/lib/python3.11/site-packages/jax/_src/interpreters/ad.py:315, in JVPTrace.process_primitive(self, primitive, tracers, params)
#     313   msg = f"Differentiation rule for '{primitive}' not implemented"
#     314   raise NotImplementedError(msg)
# --> 315 primal_out, tangent_out = jvp(primals_in, tangents_in, **params)
#     316 if primitive.multiple_results:
#     317   return [JVPTracer(self, x, t) for x, t in zip(primal_out, tangent_out)]
#
# File ~/miniforge3/envs/jf1uids/lib/python3.11/site-packages/jax/_src/pjit.py:2049, in _pjit_jvp(primals_in, tangents_in, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline)
#    2047 _filter_zeros_in = partial(_filter_zeros, is_nz_tangents_in)
#    2048 _filter_zeros_out = partial(_filter_zeros, is_nz_tangents_out)
# -> 2049 outputs = pjit_p.bind(
#    2050     *primals_in, *_filter_zeros_in(tangents_in),
#    2051     jaxpr=jaxpr_jvp,
#    2052     in_shardings=(*in_shardings, *_filter_zeros_in(in_shardings)),
#    2053     out_shardings=(*out_shardings, *_filter_zeros_out(out_shardings)),
#    2054     in_layouts=(*in_layouts, *_filter_zeros_in(in_layouts)),
#    2055     out_layouts=(*out_layouts, *_filter_zeros_out(out_layouts)),
#    2056     resource_env=resource_env,
#    2057     donated_invars=(*donated_invars, *_filter_zeros_in(donated_invars)),
#    2058     name=name,
#    2059     keep_unused=keep_unused,
#    2060     inline=inline)
#    2062 primals_out, tangents_out = split_list(outputs, [len(jaxpr.jaxpr.outvars)])
#    2063 assert len(primals_out) == len(jaxpr.jaxpr.outvars)
#
# File ~/miniforge3/envs/jf1uids/lib/python3.11/site-packages/jax/_src/core.py:2739, in AxisPrimitive.bind(self, *args, **params)
#    2735 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2736                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2737 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2738              else axis_main.with_cur_sublevel())
# -> 2739 return self.bind_with_trace(top_trace, args, params)
#
# File ~/miniforge3/envs/jf1uids/lib/python3.11/site-packages/jax/_src/core.py:433, in Primitive.bind_with_trace(self, trace, args, params)
#     431 def bind_with_trace(self, trace, args, params):
#     432   with pop_level(trace.level):
# --> 433     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     434   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniforge3/envs/jf1uids/lib/python3.11/site-packages/jax/_src/interpreters/partial_eval.py:214, in JaxprTrace.process_primitive(self, primitive, tracers, params)
#     212 def process_primitive(self, primitive, tracers, params):
#     213   if primitive in custom_partial_eval_rules:
# --> 214     return custom_partial_eval_rules[primitive](self, *tracers, **params)
#     215   else:
#     216     return self.default_process_primitive(primitive, tracers, params)
#
# File ~/miniforge3/envs/jf1uids/lib/python3.11/site-packages/jax/_src/pjit.py:2146, in _pjit_partial_eval(trace, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, *in_tracers)
#    2144 # Bind known things to pjit_p.
#    2145 known_inputs = [pv.get_known() for pv in in_pvals if pv.is_known()]
# -> 2146 all_known_outs = pjit_p.bind(*known_inputs, **known_params)
#    2147 # Add back in the output fwds.
#    2148 all_known_outs = subs_list(out_fwd, all_known_outs, all_known_outs)
#
# File ~/miniforge3/envs/jf1uids/lib/python3.11/site-packages/jax/_src/core.py:2739, in AxisPrimitive.bind(self, *args, **params)
#    2735 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2736                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2737 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2738              else axis_main.with_cur_sublevel())
# -> 2739 return self.bind_with_trace(top_trace, args, params)
#
# File ~/miniforge3/envs/jf1uids/lib/python3.11/site-packages/jax/_src/core.py:433, in Primitive.bind_with_trace(self, trace, args, params)
#     431 def bind_with_trace(self, trace, args, params):
#     432   with pop_level(trace.level):
# --> 433     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     434   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniforge3/envs/jf1uids/lib/python3.11/site-packages/jax/_src/core.py:939, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     937   return call_impl_with_key_reuse_checks(primitive, primitive.impl, *tracers, **params)
#     938 else:
# --> 939   return primitive.impl(*tracers, **params)
#
# File ~/miniforge3/envs/jf1uids/lib/python3.11/site-packages/jax/_src/pjit.py:1730, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1727 donated_argnums = [i for i, d in enumerate(donated_invars) if d]
#    1728 has_explicit_sharding = _pjit_explicit_sharding(
#    1729     in_shardings, out_shardings, None, None)
# -> 1730 return xc._xla.pjit(
#    1731     name, f, call_impl_cache_miss, [], [], donated_argnums,
#    1732     tree_util.dispatch_registry,
#    1733     lambda x, sharding: pxla.shard_args([sharding], [x])[0],
#    1734     _get_cpp_global_cache(has_explicit_sharding))(*args)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Loss map plot

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
from matplotlib.colors import LogNorm
from mpl_toolkits.axes_grid1 import make_axes_locatable

divider = make_axes_locatable(axs[0])
cax = divider.append_axes('right', size='5%', pad=0.05)
norm = LogNorm(vmin=loss_map.min(), vmax=loss_map.max())
mapper = plt.cm.ScalarMappable(norm=norm, cmap=plt.cm.viridis)
plt.colorbar(mapper, cax=cax, orientation='vertical', label='primitive state loss')

# plot as heatmap
# axs[0].imshow(loss_map, origin='lower', extent=[
#     (velocities[0] * code_units.code_velocity).to(u.km / u.s).value,
#     (velocities[-1] * code_units.code_velocity).to(u.km / u.s).value,
#     (mass_loss_rates[0] * code_units.code_mass / code_units.code_time).to(2.965e-3 / (1e6 * u.yr) * u.M_sun).value,
#     (mass_loss_rates[-1] * code_units.code_mass / code_units.code_time).to(2.965e-3 / (1e6 * u.yr) * u.M_sun).value
# ], aspect='auto', norm=norm)

axs[0].scatter((vel_list * code_units.code_velocity).to(u.km / u.s).value, (mass_list * code_units.code_mass / code_units.code_time).to(2.965e-3 / (1e6 * u.yr) * u.M_sun).value, c=loss_map, cmap='viridis', norm=norm, s = 15, marker = "s")

axs[0].set_xlabel('Final Wind Velocity in km/s')
axs[0].set_ylabel('Mass of the Star in M_sun')
axs[0].set_title('loss landscape')

# plot the loss function
axs[1].plot(loss_list1, label='loss 1', color='blue')

# plot the optimization path
xlist1 = jnp.array(xlist1)
axs[0].plot((xlist1[:, 0] * code_units.code_velocity).to(u.km / u.s).value, (xlist1[:, 1] * code_units.code_mass / code_units.code_time).to(2.965e-3 / (1e6 * u.yr) * u.M_sun).value, color='blue', label='optimization path 1')
axs[0].scatter(
    [(xlist1[0, 0] * code_units.code_velocity).to(u.km / u.s).value], [(xlist1[0, 1] * code_units.code_mass / code_units.code_time).to(2.965e-3 / (1e6 * u.yr) * u.M_sun).value],
    c='blue', s = 40
)


# plot the optimization path
xlist2 = jnp.array(xlist2)
axs[0].plot((xlist2[:, 0] * code_units.code_velocity).to(u.km / u.s).value, (xlist2[:, 1] * code_units.code_mass / code_units.code_time).to(2.965e-3 / (1e6 * u.yr) * u.M_sun).value, color='purple', label='optimization path 2')

axs[0].scatter(
    [(xlist2[0, 0] * code_units.code_velocity).to(u.km / u.s).value], [(xlist2[0, 1] * code_units.code_mass / code_units.code_time).to(2.965e-3 / (1e6 * u.yr) * u.M_sun).value],
    c='purple', s = 40
)
    

# plot the loss function
axs[1].plot(loss_list2, label='loss 2', color='purple')

# plot the optimization path
xlist3 = jnp.array(xlist3)
axs[0].plot((xlist3[:, 0] * code_units.code_velocity).to(u.km / u.s).value, (xlist3[:, 1] * code_units.code_mass / code_units.code_time).to(2.965e-3 / (1e6 * u.yr) * u.M_sun).value, color='red', label='optimization path 3')

axs[0].scatter(
    [(xlist3[0, 0] * code_units.code_velocity).to(u.km / u.s).value], [(xlist3[0, 1] * code_units.code_mass / code_units.code_time).to(2.965e-3 / (1e6 * u.yr) * u.M_sun).value],
    c='red', s = 40
)



# plot the loss function
axs[1].plot(loss_list3, label='loss 3', color='red')


axs[1].set_xlabel('iterations')
axs[1].set_ylabel('primitive state loss')
axs[1].set_title('primitive state loss convergence')
# log y
axs[1].set_yscale('log')
# top right legend
axs[1].legend(loc='upper right')
plt.tight_layout()

# mark the true value as a red dot
axs[0].scatter(
    [wind_final_velocity.to(u.km / u.s).value],
    [wind_mass_loss_rate.to(2.965e-3 / (1e6 * u.yr) * u.M_sun).value],
    c='white', s = 200, label='true wind parameters', marker = "*", zorder = 10, edgecolors='black'
)


axs[0].legend()
axs[1].legend()

# axs 1 y lim 10^6 to 3 * 10^9
axs[1].set_ylim(1e6, 3e9)

# print(full_profile_loss(((2000 * u.km / u.s).to(code_units.code_velocity).value, (2.965e-3 / (1e6 * u.yr) * 40 * u.M_sun).to(code_units.code_mass / code_units.code_time).value)))

plt.savefig('optimizationB.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 26
#      23 axs[0].set_title('loss landscape')
#      25 # plot the loss function
# ---> 26 axs[1].plot(loss_list1, label='loss 1', color='blue')
#      28 # plot the optimization path
#      29 xlist1 = jnp.array(xlist1)
#
# NameError: name 'loss_list1' is not defined
