# %% [markdown]
# # Gradient Descent for Finding Stellar Wind Parameters

# %% [markdown]
# ## Imports

# %%
# numerics
import jax
import jax.numpy as jnp
import numpy as np
import optax

# timing
from timeit import default_timer as timer

# plotting
import matplotlib.pyplot as plt

# fluids
from jf1uids.boundaries import OPEN_BOUNDARY, REFLECTIVE_BOUNDARY
from jf1uids.geometry import SPHERICAL
from jf1uids.physics_modules.stellar_wind import WindParams
from jf1uids.postprocessing import shock_sensor, strongest_shock_radius
from jf1uids.simulation_config import SimulationConfig
from jf1uids.simulation_helper_data import get_helper_data
from jf1uids.simulation_params import SimulationParams
from jf1uids.time_integration import time_integration
from jf1uids.fluid import primitive_state

# units
from jf1uids.unit_helpers import CodeUnits
from astropy import units as u
import astropy.constants as c
from astropy.constants import m_p

# wind-specific
from weaver import Weaver
from jax import grad

# # for now using CPU as of outdated NVIDIA Driver
jax.config.update('jax_platform_name', 'cpu')

# # 64-bit precision
jax.config.update("jax_enable_x64", True)

# %% [markdown]
# ## Initiating the stellar wind simulation

# %%
print("👷 Setting up simulation...")

# simulation settings
gamma = 5/3

# spatial domain
alpha = SPHERICAL
box_size = 1.0
num_cells = 100
dx = box_size / num_cells

fixed_timestep = True
num_timesteps = 4000

# introduce constants to 
# make this more readable
left_boundary = REFLECTIVE_BOUNDARY
right_boundary = OPEN_BOUNDARY

# activate stellar wind
stellar_wind = True

# setup simulation config
config = SimulationConfig(
    alpha_geom = alpha,
    box_size = box_size, 
    num_cells = num_cells,
    left_boundary = left_boundary, 
    right_boundary = right_boundary, 
    stellar_wind = stellar_wind,
    fixed_timestep = fixed_timestep,
    num_timesteps = num_timesteps
)

helper_data = get_helper_data(config)
# Out:
# 👷 Setting up simulation...

# %% [markdown]
# ## Setting the simulation parameters and initial state

# %%
# code units
code_length = 3 * u.parsec
code_mass = 1e-4 * u.M_sun
code_velocity = 1 * u.km / u.s
code_units = CodeUnits(code_length, code_mass, code_velocity)

# time domain
C_CFL = 0.8
t_final = 2.5 * 1e4 * u.yr
t_end = t_final.to(code_units.code_time).value
dt_max = 0.0001 * t_end

params = SimulationParams(
    C_cfl = C_CFL,
    dt_max = dt_max,
    dx = dx,
    gamma = gamma,
    t_end = t_end
)

# homogeneous initial state
rho_0 = 2 * c.m_p / u.cm**3
p_0 = 3e4 * u.K / u.cm**3 * c.k_B

rho_init = jnp.ones(num_cells) * rho_0.to(code_units.code_density).value
u_init = jnp.zeros(num_cells)
p_init = jnp.ones(num_cells) * p_0.to(code_units.code_pressure).value

# get initial state
initial_state = primitive_state(rho_init, u_init, p_init)

# %% [markdown]
# ## Setting up a reference simulation

# %%
sample_simulation = lambda velocity, mass_loss_rate: time_integration(initial_state, config, SimulationParams(
    C_cfl=params.C_cfl,
    dt_max=params.dt_max,
    dx=params.dx,
    gamma=params.gamma,
    t_end=params.t_end,
    wind_params=WindParams(
        wind_mass_loss_rate=mass_loss_rate,
        wind_final_velocity=velocity
    )
), helper_data)

# generate a reference simulation
M_star = 40 * u.M_sun
wind_final_velocity = 2000 * u.km / u.s
wind_mass_loss_rate = 2.965e-3 / (1e6 * u.yr) * M_star

reference_params = WindParams(
    wind_mass_loss_rate = wind_mass_loss_rate.to(code_units.code_mass / code_units.code_time).value,
    wind_final_velocity = wind_final_velocity.to(code_units.code_velocity).value
)

reference_simulation = sample_simulation(
    reference_params.wind_final_velocity,
    reference_params.wind_mass_loss_rate
)

reference_shock_radius = strongest_shock_radius(reference_simulation, helper_data, 10, 5)

# %% [markdown]
# ## Losses

# %%
def density_loss(vel_mass_loss):
    velocity = vel_mass_loss[0]
    mass_loss_rate = vel_mass_loss[1]
    final_state = sample_simulation(velocity, mass_loss_rate)
    return jnp.mean(jnp.abs(final_state[0] - reference_simulation[0]))

def full_profile_loss(vel_mass_loss):
    velocity = vel_mass_loss[0]
    mass_loss_rate = vel_mass_loss[1]
    final_state = sample_simulation(velocity, mass_loss_rate)
    return jnp.sum(jnp.abs(final_state - reference_simulation))

def shock_radius_loss(vel_mass_loss):
    velocity = vel_mass_loss[0]
    mass_loss_rate = vel_mass_loss[1]
    final_state = sample_simulation(velocity, mass_loss_rate)
    return jnp.abs(strongest_shock_radius(final_state, helper_data, 10, 5) - reference_shock_radius)

# %% [markdown]
# ## Loss map

# %%
def get_loss_map(velocity_range, mass_loss_rate_range):
    loss_map = jnp.zeros((len(velocity_range) * len(mass_loss_rate_range),))
    vel_list = jnp.zeros((len(velocity_range) * len(mass_loss_rate_range),))
    mass_list = jnp.zeros((len(velocity_range) * len(mass_loss_rate_range),))
    ind = 0

    for i, velocity in enumerate(velocity_range):
        for j, mass_loss_rate in enumerate(mass_loss_rate_range):
            loss_map = loss_map.at[ind].set(density_loss((velocity, mass_loss_rate)))
            vel_list = vel_list.at[ind].set(velocity)
            mass_list = mass_list.at[ind].set(mass_loss_rate)
            ind += 1
    return loss_map, vel_list, mass_list

# generate a loss map
mass_loss_rates = jnp.linspace(
    (2.965e-3 / (1e6 * u.yr) * 15 * u.M_sun).to(code_units.code_mass / code_units.code_time).value,
    (2.965e-3 / (1e6 * u.yr) * 70 * u.M_sun).to(code_units.code_mass / code_units.code_time).value,
    60
)

velocities = jnp.linspace(
    (200 * u.km / u.s).to(code_units.code_velocity).value,
    (4000 * u.km / u.s).to(code_units.code_velocity).value,
    60
)

loss_map, vel_list, mass_list = get_loss_map(velocities, mass_loss_rates)

# %% [markdown]
# ## Optimization

# %%
# def newton_optimization(func, x_init, tol=1e-6, max_iter=1000):
#     x = x_init
#     for _ in range(max_iter):
#         # Compute the function value and its gradient
#         f_grad = jax.grad(func)(x)
        
#         # Compute the Hessian matrix
#         f_hessian = jax.hessian(func)(x)
        
#         # Compute the Newton update step
#         delta_x = jnp.linalg.solve(f_hessian, -f_grad)
        
#         # Update the parameter
#         x += delta_x

#         print(f"Optimal wind final velocity: {(x[0] * code_units.code_velocity).to(u.km / u.s)}")
#         print(f"Optimal wind mass loss rate: {(x[1] * code_units.code_mass / code_units.code_time).to(2.965e-3 / (1e6 * u.yr) * u.M_sun)}")

        
#         # Check convergence
#         if jnp.linalg.norm(delta_x) < tol:
#             break
    
#     return x

# also implement gradient descent
def gradient_descent_optimization(func, x_init, learning_rate=1e-5, tol=1e-6, max_iter=2000):
    xlist = []
    x = x_init
    loss_list = []
    xlist.append(x)
    print(f"Optimal wind final velocity: {x[0]}")
    print(f"Optimal wind mass loss rate: {x[1]}")

    for _ in range(max_iter):
        # Compute the function value and its gradient
        # f_grad = jax.grad(func)(x)
        loss, f_grad = jax.value_and_grad(func)(x)
        loss_list.append(loss)
        
        # Update the parameter
        x -= learning_rate * f_grad
        xlist.append(x)

        print(f"Optimal wind final velocity: {(x[0] * code_units.code_velocity).to(u.km / u.s)}")
        print(f"Optimal wind mass loss rate: {(x[1] * code_units.code_mass / code_units.code_time).to(2.965e-3 / (1e6 * u.yr) * u.M_sun)}")

        # Check convergence
        if jnp.linalg.norm(learning_rate * f_grad) < tol:
            break
    
    return x, xlist, loss_list

def random_wind_initialization(v_min, v_max, m_min, m_max):
    # pick a random velocity and mass loss rate between the given ranges
    velocity = np.random.uniform(v_min, v_max)
    mass_loss_rate = np.random.uniform(m_min, m_max)
    return jnp.array([velocity, mass_loss_rate])

# get a random initial guess
initial_guess = random_wind_initialization(
    (200 * u.km / u.s).to(code_units.code_velocity).value,
    (4000 * u.km / u.s).to(code_units.code_velocity).value,
    (2.965e-3 / (1e6 * u.yr) * 15 * u.M_sun).to(code_units.code_mass / code_units.code_time).value,
    (2.965e-3 / (1e6 * u.yr) * 70 * u.M_sun).to(code_units.code_mass / code_units.code_time).value
)

# print(initial_guess)


# M_star_optim = 30 * u.M_sun
# wind_final_velocity_optim = (1500 * u.km / u.s).to(code_units.code_velocity).value
# wind_mass_loss_rate_optim = (2.965e-3 / (1e6 * u.yr) * M_star_optim).to(code_units.code_mass / code_units.code_time).value

# vel_mass_loss_optim = jnp.array([wind_final_velocity_optim, wind_mass_loss_rate_optim])

# optimize the mass loss rate and final velocity using gradient descent
# optimized_params = gradient_descent_optimization(density_loss, vel_mass_loss_optim)

# %% [markdown]
# ## Example loss paths

# %%
# random initialization 1
# initial_guess = random_wind_initialization(
#     (1000 * u.km / u.s).to(code_units.code_velocity).value,
#     (3500 * u.km / u.s).to(code_units.code_velocity).value,
#     (2.965e-3 / (1e6 * u.yr) * 10 * u.M_sun).to(code_units.code_mass / code_units.code_time).value,
#     (2.965e-3 / (1e6 * u.yr) * 70 * u.M_sun).to(code_units.code_mass / code_units.code_time).value
# )
initial_guess1 = jnp.array([(1500 * u.km / u.s).to(code_units.code_velocity).value, (2.965e-3 / (1e6 * u.yr) * 30 * u.M_sun).to(code_units.code_mass / code_units.code_time).value])
x1, xlist1, loss_list1 = gradient_descent_optimization(full_profile_loss, initial_guess1)

# random initialization 2
# initial_guess = random_wind_initialization(
#     (1000 * u.km / u.s).to(code_units.code_velocity).value,
#     (3500 * u.km / u.s).to(code_units.code_velocity).value,
#     (2.965e-3 / (1e6 * u.yr) * 10 * u.M_sun).to(code_units.code_mass / code_units.code_time).value,
#     (2.965e-3 / (1e6 * u.yr) * 70 * u.M_sun).to(code_units.code_mass / code_units.code_time).value
# )
initial_guess2 = jnp.array([(3500 * u.km / u.s).to(code_units.code_velocity).value, (2.965e-3 / (1e6 * u.yr) * 60 * u.M_sun).to(code_units.code_mass / code_units.code_time).value])
x2, xlist2, loss_list2 = gradient_descent_optimization(full_profile_loss, initial_guess2)

# random initialization 3
# initial_guess = random_wind_initialization(
#     (1000 * u.km / u.s).to(code_units.code_velocity).value,
#     (3500 * u.km / u.s).to(code_units.code_velocity).value,
#     (2.965e-3 / (1e6 * u.yr) * 10 * u.M_sun).to(code_units.code_mass / code_units.code_time).value,
#     (2.965e-3 / (1e6 * u.yr) * 70 * u.M_sun).to(code_units.code_mass / code_units.code_time).value
# )
initial_guess3 = jnp.array([(3300 * u.km / u.s).to(code_units.code_velocity).value, (2.965e-3 / (1e6 * u.yr) * 45 * u.M_sun).to(code_units.code_mass / code_units.code_time).value])
x3, xlist3, loss_list3 = gradient_descent_optimization(full_profile_loss, initial_guess3)
# Out:
# Optimal wind final velocity: 1500.0
# Optimal wind mass loss rate: 2609.2385435551855
# Optimal wind final velocity: 1506.277836442183 km / s
# Optimal wind mass loss rate: 30.024441358217143 2.965e-09 solMass / yr
# Optimal wind final velocity: 1512.5752237812462 km / s
# Optimal wind mass loss rate: 30.04905901871116 2.965e-09 solMass / yr
# Optimal wind final velocity: 1518.8913583768815 km / s
# Optimal wind mass loss rate: 30.073851053450884 2.965e-09 solMass / yr
# Optimal wind final velocity: 1525.222391489857 km / s
# Optimal wind mass loss rate: 30.098805169245978 2.965e-09 solMass / yr
# Optimal wind final velocity: 1531.5674490589436 km / s
# Optimal wind mass loss rate: 30.123918691462332 2.965e-09 solMass / yr
# Optimal wind final velocity: 1537.9216112963215 km / s
# Optimal wind mass loss rate: 30.14917539684579 2.965e-09 solMass / yr
# Optimal wind final velocity: 1544.2791691959417 km / s
# Optimal wind mass loss rate: 30.174556268335188 2.965e-09 solMass / yr
# Optimal wind final velocity: 1550.6417221945364 km / s
# Optimal wind mass loss rate: 30.200066902379145 2.965e-09 solMass / yr
# Optimal wind final velocity: 1557.017091652997 km / s
# Optimal wind mass loss rate: 30.225734249016206 2.965e-09 solMass / yr
# Optimal wind final velocity: 1563.4009092044694 km / s
# Optimal wind mass loss rate: 30.251543923210548 2.965e-09 solMass / yr
# Optimal wind final velocity: 1569.8030032893794 km / s
# Optimal wind mass loss rate: 30.27753001823431 2.965e-09 solMass / yr
# Optimal wind final velocity: 1576.2235089727299 km / s
# Optimal wind mass loss rate: 30.30369397967598 2.965e-09 solMass / yr
# Optimal wind final velocity: 1582.6641617701398 km / s
# Optimal wind mass loss rate: 30.33004263043208 2.965e-09 solMass / yr
# Optimal wind final velocity: 1589.1170920671548 km / s
# Optimal wind mass loss rate: 30.35654946468863 2.965e-09 solMass / yr
# Optimal wind final velocity: 1595.4693213812563 km / s
# Optimal wind mass loss rate: 30.382985149170022 2.965e-09 solMass / yr
# Optimal wind final velocity: 1601.8313214768878 km / s
# Optimal wind mass loss rate: 30.40956918651458 2.965e-09 solMass / yr
# Optimal wind final velocity: 1608.197996136533 km / s
# Optimal wind mass loss rate: 30.436283953233634 2.965e-09 solMass / yr
# Optimal wind final velocity: 1614.5700010649232 km / s
# Optimal wind mass loss rate: 30.463132943986157 2.965e-09 solMass / yr
# Optimal wind final velocity: 1620.954669515699 km / s
# Optimal wind mass loss rate: 30.49014222989992 2.965e-09 solMass / yr
# Optimal wind final velocity: 1627.3477475874267 km / s
# Optimal wind mass loss rate: 30.517297658638483 2.965e-09 solMass / yr
# Optimal wind final velocity: 1633.764605754548 km / s
# Optimal wind mass loss rate: 30.544654613662175 2.965e-09 solMass / yr
# Optimal wind final velocity: 1640.1999636422663 km / s
# Optimal wind mass loss rate: 30.572195841265124 2.965e-09 solMass / yr
# Optimal wind final velocity: 1646.6554440044758 km / s
# Optimal wind mass loss rate: 30.599928414996604 2.965e-09 solMass / yr
# Optimal wind final velocity: 1653.1220490615408 km / s
# Optimal wind mass loss rate: 30.627821591064457 2.965e-09 solMass / yr
# Optimal wind final velocity: 1659.613389376842 km / s
# Optimal wind mass loss rate: 30.65609808133345 2.965e-09 solMass / yr
# Optimal wind final velocity: 1666.1379226163897 km / s
# Optimal wind mass loss rate: 30.685052262010938 2.965e-09 solMass / yr
# Optimal wind final velocity: 1672.6825454918835 km / s
# Optimal wind mass loss rate: 30.714383708906276 2.965e-09 solMass / yr
# Optimal wind final velocity: 1679.2454419520739 km / s
# Optimal wind mass loss rate: 30.743990299633058 2.965e-09 solMass / yr
# Optimal wind final velocity: 1685.8235492885678 km / s
# Optimal wind mass loss rate: 30.77384420662714 2.965e-09 solMass / yr
# Optimal wind final velocity: 1692.4169721031574 km / s
# Optimal wind mass loss rate: 30.80390084415294 2.965e-09 solMass / yr
# Optimal wind final velocity: 1699.0152913820089 km / s
# Optimal wind mass loss rate: 30.83382967366966 2.965e-09 solMass / yr
# Optimal wind final velocity: 1705.6406616142701 km / s
# Optimal wind mass loss rate: 30.86412214263276 2.965e-09 solMass / yr
# Optimal wind final velocity: 1712.28757957841 km / s
# Optimal wind mass loss rate: 30.894672730019007 2.965e-09 solMass / yr
# Optimal wind final velocity: 1718.946568510821 km / s
# Optimal wind mass loss rate: 30.925396276818173 2.965e-09 solMass / yr
# Optimal wind final velocity: 1725.6214779090037 km / s
# Optimal wind mass loss rate: 30.95641787213276 2.965e-09 solMass / yr
# Optimal wind final velocity: 1732.3256617476845 km / s
# Optimal wind mass loss rate: 30.98800015855434 2.965e-09 solMass / yr
# Optimal wind final velocity: 1739.0687525932299 km / s
# Optimal wind mass loss rate: 31.02031902881975 2.965e-09 solMass / yr
# Optimal wind final velocity: 1745.8108038449125 km / s
# Optimal wind mass loss rate: 31.052555837801386 2.965e-09 solMass / yr
# Optimal wind final velocity: 1752.556592914988 km / s
# Optimal wind mass loss rate: 31.08479582057115 2.965e-09 solMass / yr
# Optimal wind final velocity: 1759.3228990499404 km / s
# Optimal wind mass loss rate: 31.117150742350248 2.965e-09 solMass / yr
# Optimal wind final velocity: 1766.1024865832371 km / s
# Optimal wind mass loss rate: 31.149595434563963 2.965e-09 solMass / yr
# Optimal wind final velocity: 1772.899525215105 km / s
# Optimal wind mass loss rate: 31.182172798860577 2.965e-09 solMass / yr
# Optimal wind final velocity: 1779.6994894364018 km / s
# Optimal wind mass loss rate: 31.214827516489475 2.965e-09 solMass / yr
# Optimal wind final velocity: 1786.5050635314453 km / s
# Optimal wind mass loss rate: 31.24757535034623 2.965e-09 solMass / yr
# Optimal wind final velocity: 1793.314155831116 km / s
# Optimal wind mass loss rate: 31.28041118477724 2.965e-09 solMass / yr
# Optimal wind final velocity: 1800.1299294852586 km / s
# Optimal wind mass loss rate: 31.31334800993873 2.965e-09 solMass / yr
# Optimal wind final velocity: 1806.953274016529 km / s
# Optimal wind mass loss rate: 31.3463910757068 2.965e-09 solMass / yr
# Optimal wind final velocity: 1813.7897657635388 km / s
# Optimal wind mass loss rate: 31.379565991457955 2.965e-09 solMass / yr
# Optimal wind final velocity: 1820.638735700993 km / s
# Optimal wind mass loss rate: 31.412874256690817 2.965e-09 solMass / yr
# Optimal wind final velocity: 1827.5049965219343 km / s
# Optimal wind mass loss rate: 31.446336550062043 2.965e-09 solMass / yr
# Optimal wind final velocity: 1834.3954507498302 km / s
# Optimal wind mass loss rate: 31.47998254436042 2.965e-09 solMass / yr
# Optimal wind final velocity: 1841.293393652183 km / s
# Optimal wind mass loss rate: 31.513749756188354 2.965e-09 solMass / yr
# Optimal wind final velocity: 1848.2034437372045 km / s
# Optimal wind mass loss rate: 31.547657792158333 2.965e-09 solMass / yr
# Optimal wind final velocity: 1855.1133250463959 km / s
# Optimal wind mass loss rate: 31.581660611915343 2.965e-09 solMass / yr
# Optimal wind final velocity: 1862.0316690202626 km / s
# Optimal wind mass loss rate: 31.615793205540484 2.965e-09 solMass / yr
# Optimal wind final velocity: 1868.9573275694147 km / s
# Optimal wind mass loss rate: 31.650052505157216 2.965e-09 solMass / yr
# Optimal wind final velocity: 1875.8928739840378 km / s
# Optimal wind mass loss rate: 31.684449057332056 2.965e-09 solMass / yr
# Optimal wind final velocity: 1882.844347478916 km / s
# Optimal wind mass loss rate: 31.719006273141954 2.965e-09 solMass / yr
# Optimal wind final velocity: 1889.8187116348265 km / s
# Optimal wind mass loss rate: 31.753750761301035 2.965e-09 solMass / yr
# Optimal wind final velocity: 1896.80737256904 km / s
# Optimal wind mass loss rate: 31.788647817153034 2.965e-09 solMass / yr
# Optimal wind final velocity: 1903.8156790575729 km / s
# Optimal wind mass loss rate: 31.823719158219497 2.965e-09 solMass / yr
# Optimal wind final velocity: 1910.827555837881 km / s
# Optimal wind mass loss rate: 31.85889608090168 2.965e-09 solMass / yr
# Optimal wind final velocity: 1917.8483465730421 km / s
# Optimal wind mass loss rate: 31.894199152065863 2.965e-09 solMass / yr
# Optimal wind final velocity: 1924.873771629731 km / s
# Optimal wind mass loss rate: 31.929611025368743 2.965e-09 solMass / yr
# Optimal wind final velocity: 1931.907361270716 km / s
# Optimal wind mass loss rate: 31.965144118601454 2.965e-09 solMass / yr
# Optimal wind final velocity: 1938.951504700987 km / s
# Optimal wind mass loss rate: 32.00080874335855 2.965e-09 solMass / yr
# Optimal wind final velocity: 1946.0064758479919 km / s
# Optimal wind mass loss rate: 32.03660378948878 2.965e-09 solMass / yr
# Optimal wind final velocity: 1953.0818800428606 km / s
# Optimal wind mass loss rate: 32.072571401916385 2.965e-09 solMass / yr
# Optimal wind final velocity: 1960.1752543412172 km / s
# Optimal wind mass loss rate: 32.10870129740295 2.965e-09 solMass / yr
# Optimal wind final velocity: 1967.285406739659 km / s
# Optimal wind mass loss rate: 32.14499081936172 2.965e-09 solMass / yr
# Optimal wind final velocity: 1974.4046564280745 km / s
# Optimal wind mass loss rate: 32.18140523070243 2.965e-09 solMass / yr
# Optimal wind final velocity: 1981.5311864277876 km / s
# Optimal wind mass loss rate: 32.21794366831248 2.965e-09 solMass / yr
# Optimal wind final velocity: 1988.6596735972346 km / s
# Optimal wind mass loss rate: 32.2546022006916 2.965e-09 solMass / yr
# Optimal wind final velocity: 1995.7943363227812 km / s
# Optimal wind mass loss rate: 32.291316903044134 2.965e-09 solMass / yr
# Optimal wind final velocity: 2002.9282813340926 km / s
# Optimal wind mass loss rate: 32.32794199899267 2.965e-09 solMass / yr
# Optimal wind final velocity: 2010.09406827654 km / s
# Optimal wind mass loss rate: 32.36509172517332 2.965e-09 solMass / yr
# Optimal wind final velocity: 2017.2964396979223 km / s
# Optimal wind mass loss rate: 32.402846641191715 2.965e-09 solMass / yr
# Optimal wind final velocity: 2024.5352770411323 km / s
# Optimal wind mass loss rate: 32.441106245077926 2.965e-09 solMass / yr
# Optimal wind final velocity: 2031.8009620375017 km / s
# Optimal wind mass loss rate: 32.47973033207371 2.965e-09 solMass / yr
# Optimal wind final velocity: 2039.0824370510848 km / s
# Optimal wind mass loss rate: 32.5185790825759 2.965e-09 solMass / yr
# Optimal wind final velocity: 2046.3755628114193 km / s
# Optimal wind mass loss rate: 32.55765491753959 2.965e-09 solMass / yr
# Optimal wind final velocity: 2053.674219916387 km / s
# Optimal wind mass loss rate: 32.59695631111619 2.965e-09 solMass / yr
# Optimal wind final velocity: 2060.9893034338925 km / s
# Optimal wind mass loss rate: 32.636521810578394 2.965e-09 solMass / yr
# Optimal wind final velocity: 2068.3212628330803 km / s
# Optimal wind mass loss rate: 32.67631098951009 2.965e-09 solMass / yr
# Optimal wind final velocity: 2075.6603007468966 km / s
# Optimal wind mass loss rate: 32.71623567704322 2.965e-09 solMass / yr
# Optimal wind final velocity: 2083.0234685895334 km / s
# Optimal wind mass loss rate: 32.75633481716094 2.965e-09 solMass / yr
# Optimal wind final velocity: 2090.4069680902476 km / s
# Optimal wind mass loss rate: 32.79658739598279 2.965e-09 solMass / yr
# Optimal wind final velocity: 2097.7226800733033 km / s
# Optimal wind mass loss rate: 32.83737312333462 2.965e-09 solMass / yr
# Optimal wind final velocity: 2105.0664795726466 km / s
# Optimal wind mass loss rate: 32.878627994326074 2.965e-09 solMass / yr
# Optimal wind final velocity: 2112.4239959724964 km / s
# Optimal wind mass loss rate: 32.920197978160644 2.965e-09 solMass / yr
# Optimal wind final velocity: 2119.798146833573 km / s
# Optimal wind mass loss rate: 32.96214291985682 2.965e-09 solMass / yr
# Optimal wind final velocity: 2127.194870791474 km / s
# Optimal wind mass loss rate: 33.00453761390258 2.965e-09 solMass / yr
# Optimal wind final velocity: 2134.616919979699 km / s
# Optimal wind mass loss rate: 33.04745724692949 2.965e-09 solMass / yr
# Optimal wind final velocity: 2141.9560298366055 km / s
# Optimal wind mass loss rate: 33.090524256227084 2.965e-09 solMass / yr
# Optimal wind final velocity: 2149.328568362354 km / s
# Optimal wind mass loss rate: 33.13401574537799 2.965e-09 solMass / yr
# Optimal wind final velocity: 2156.7301298018647 km / s
# Optimal wind mass loss rate: 33.17785446156084 2.965e-09 solMass / yr
# Optimal wind final velocity: 2163.9124977353267 km / s
# Optimal wind mass loss rate: 33.21819925470597 2.965e-09 solMass / yr
# Optimal wind final velocity: 2170.9827109784214 km / s
# Optimal wind mass loss rate: 33.258368499249 2.965e-09 solMass / yr
# Optimal wind final velocity: 2177.9390381484886 km / s
# Optimal wind mass loss rate: 33.29835215606438 2.965e-09 solMass / yr
# Optimal wind final velocity: 2184.776458512285 km / s
# Optimal wind mass loss rate: 33.338124520226216 2.965e-09 solMass / yr
# Optimal wind final velocity: 2191.2830884878927 km / s
# Optimal wind mass loss rate: 33.377907202323335 2.965e-09 solMass / yr
# Optimal wind final velocity: 2196.3389443631013 km / s
# Optimal wind mass loss rate: 33.41206053633644 2.965e-09 solMass / yr
# Optimal wind final velocity: 2192.001825323485 km / s
# Optimal wind mass loss rate: 33.40448754605118 2.965e-09 solMass / yr
# Optimal wind final velocity: 2192.897276157797 km / s
# Optimal wind mass loss rate: 33.420199597167766 2.965e-09 solMass / yr
# Optimal wind final velocity: 2189.2288008079195 km / s
# Optimal wind mass loss rate: 33.41569092307616 2.965e-09 solMass / yr
# Optimal wind final velocity: 2194.810660741645 km / s
# Optimal wind mass loss rate: 33.45205470764096 2.965e-09 solMass / yr
# Optimal wind final velocity: 2190.4703943548516 km / s
# Optimal wind mass loss rate: 33.44435087464632 2.965e-09 solMass / yr
# Optimal wind final velocity: 2192.2267186288173 km / s
# Optimal wind mass loss rate: 33.46372011656175 2.965e-09 solMass / yr
# Optimal wind final velocity: 2188.458062355241 km / s
# Optimal wind mass loss rate: 33.45858515756903 2.965e-09 solMass / yr
# Optimal wind final velocity: 2193.5123654688364 km / s
# Optimal wind mass loss rate: 33.49244014836884 2.965e-09 solMass / yr
# Optimal wind final velocity: 2189.162148107963 km / s
# Optimal wind mass loss rate: 33.48456989418304 2.965e-09 solMass / yr
# Optimal wind final velocity: 2190.9134859158507 km / s
# Optimal wind mass loss rate: 33.503754593452896 2.965e-09 solMass / yr
# Optimal wind final velocity: 2187.136320349537 km / s
# Optimal wind mass loss rate: 33.49845494072603 2.965e-09 solMass / yr
# Optimal wind final velocity: 2192.187123246101 km / s
# Optimal wind mass loss rate: 33.53209616022007 2.965e-09 solMass / yr
# Optimal wind final velocity: 2187.8284766066404 km / s
# Optimal wind mass loss rate: 33.52406504406977 2.965e-09 solMass / yr
# Optimal wind final velocity: 2189.57453449802 km / s
# Optimal wind mass loss rate: 33.54305475572798 2.965e-09 solMass / yr
# Optimal wind final velocity: 2185.7886799078988 km / s
# Optimal wind mass loss rate: 33.53758884678649 2.965e-09 solMass / yr
# Optimal wind final velocity: 2190.9757439831756 km / s
# Optimal wind mass loss rate: 33.57161160977168 2.965e-09 solMass / yr
# Optimal wind final velocity: 2186.602057183585 km / s
# Optimal wind mass loss rate: 33.56339338009288 2.965e-09 solMass / yr
# Optimal wind final velocity: 2188.3407563757905 km / s
# Optimal wind mass loss rate: 33.58218133108217 2.965e-09 solMass / yr
# Optimal wind final velocity: 2184.545411671781 km / s
# Optimal wind mass loss rate: 33.57654679303102 2.965e-09 solMass / yr
# Optimal wind final velocity: 2189.727951207734 km / s
# Optimal wind mass loss rate: 33.61034564212324 2.965e-09 solMass / yr
# Optimal wind final velocity: 2185.344634838033 km / s
# Optimal wind mass loss rate: 33.60196140803515 2.965e-09 solMass / yr
# Optimal wind final velocity: 2186.943651712719 km / s
# Optimal wind mass loss rate: 33.619964427314514 2.965e-09 solMass / yr
# Optimal wind final velocity: 2183.142774195365 km / s
# Optimal wind mass loss rate: 33.61417705105111 2.965e-09 solMass / yr
# Optimal wind final velocity: 2188.330160568472 km / s
# Optimal wind mass loss rate: 33.64779090491593 2.965e-09 solMass / yr
# Optimal wind final velocity: 2183.943603756852 km / s
# Optimal wind mass loss rate: 33.639264904310096 2.965e-09 solMass / yr
# Optimal wind final velocity: 2185.6742222796274 km / s
# Optimal wind mass loss rate: 33.65767720975004 2.965e-09 solMass / yr
# Optimal wind final velocity: 2181.8657628020546 km / s
# Optimal wind mass loss rate: 33.65172553767573 2.965e-09 solMass / yr
# Optimal wind final velocity: 2187.049067041876 km / s
# Optimal wind mass loss rate: 33.68511981655831 2.965e-09 solMass / yr
# Optimal wind final velocity: 2182.656766054531 km / s
# Optimal wind mass loss rate: 33.67643232224547 2.965e-09 solMass / yr
# Optimal wind final velocity: 2184.380225579735 km / s
# Optimal wind mass loss rate: 33.69464029317663 2.965e-09 solMass / yr
# Optimal wind final velocity: 2180.5637762046013 km / s
# Optimal wind mass loss rate: 33.688580862006276 2.965e-09 solMass / yr
# Optimal wind final velocity: 2185.86315677827 km / s
# Optimal wind mass loss rate: 33.72226826914361 2.965e-09 solMass / yr
# Optimal wind final velocity: 2181.4630014631452 km / s
# Optimal wind mass loss rate: 33.71339670343363 2.965e-09 solMass / yr
# Optimal wind final velocity: 2183.179806644063 km / s
# Optimal wind mass loss rate: 33.73139779847861 2.965e-09 solMass / yr
# Optimal wind final velocity: 2179.3530546181773 km / s
# Optimal wind mass loss rate: 33.72514443847879 2.965e-09 solMass / yr
# Optimal wind final velocity: 2184.6477169432783 km / s
# Optimal wind mass loss rate: 33.758599504063206 2.965e-09 solMass / yr
# Optimal wind final velocity: 2180.2323053085797 km / s
# Optimal wind mass loss rate: 33.7494945972988 2.965e-09 solMass / yr
# Optimal wind final velocity: 2181.945983553624 km / s
# Optimal wind mass loss rate: 33.767359498000204 2.965e-09 solMass / yr
# Optimal wind final velocity: 2178.109104062693 km / s
# Optimal wind mass loss rate: 33.760896714881774 2.965e-09 solMass / yr
# Optimal wind final velocity: 2183.4038196539213 km / s
# Optimal wind mass loss rate: 33.794196645465355 2.965e-09 solMass / yr
# Optimal wind final velocity: 2178.967107631941 km / s
# Optimal wind mass loss rate: 33.7848965852397 2.965e-09 solMass / yr
# Optimal wind final velocity: 2180.6743365005987 km / s
# Optimal wind mass loss rate: 33.80252962871623 2.965e-09 solMass / yr
# Optimal wind final velocity: 2176.8226499133484 km / s
# Optimal wind mass loss rate: 33.79582015294355 2.965e-09 solMass / yr
# Optimal wind final velocity: 2182.2538097140587 km / s
# Optimal wind mass loss rate: 33.82946406697296 2.965e-09 solMass / yr
# Optimal wind final velocity: 2177.803584666315 km / s
# Optimal wind mass loss rate: 33.81990945199446 2.965e-09 solMass / yr
# Optimal wind final velocity: 2179.5030867273554 km / s
# Optimal wind mass loss rate: 33.83728941037952 2.965e-09 solMass / yr
# Optimal wind final velocity: 2175.64371083218 km / s
# Optimal wind mass loss rate: 33.83043145304616 2.965e-09 solMass / yr
# Optimal wind final velocity: 2181.179163348291 km / s
# Optimal wind mass loss rate: 33.86427974313047 2.965e-09 solMass / yr
# Optimal wind final velocity: 2176.7163324415556 km / s
# Optimal wind mass loss rate: 33.85446623526467 2.965e-09 solMass / yr
# Optimal wind final velocity: 2178.4087583671667 km / s
# Optimal wind mass loss rate: 33.87166405819676 2.965e-09 solMass / yr
# Optimal wind final velocity: 2174.535507125939 km / s
# Optimal wind mass loss rate: 33.86453857027663 2.965e-09 solMass / yr
# Optimal wind final velocity: 2179.9565538408 km / s
# Optimal wind mass loss rate: 33.897693997891096 2.965e-09 solMass / yr
# Optimal wind final velocity: 2175.483236802531 km / s
# Optimal wind mass loss rate: 33.88770775614368 2.965e-09 solMass / yr
# Optimal wind final velocity: 2177.1756570027196 km / s
# Optimal wind mass loss rate: 33.9046612824942 2.965e-09 solMass / yr
# Optimal wind final velocity: 2173.2948591963273 km / s
# Optimal wind mass loss rate: 33.897373972173995 2.965e-09 solMass / yr
# Optimal wind final velocity: 2178.818192752808 km / s
# Optimal wind mass loss rate: 33.930692254079965 2.965e-09 solMass / yr
# Optimal wind final velocity: 2174.3319977096985 km / s
# Optimal wind mass loss rate: 33.920446618449446 2.965e-09 solMass / yr
# Optimal wind final velocity: 2177.127779660016 km / s
# Optimal wind mass loss rate: 33.941919106438746 2.965e-09 solMass / yr
# Optimal wind final velocity: 2173.2137995904436 km / s
# Optimal wind mass loss rate: 33.93419826188943 2.965e-09 solMass / yr
# Optimal wind final velocity: 2177.961205444615 km / s
# Optimal wind mass loss rate: 33.963950059344555 2.965e-09 solMass / yr
# Optimal wind final velocity: 2173.4647786357154 km / s
# Optimal wind mass loss rate: 33.953539417904906 2.965e-09 solMass / yr
# Optimal wind final velocity: 2175.1297728185104 km / s
# Optimal wind mass loss rate: 33.96996584371377 2.965e-09 solMass / yr
# Optimal wind final velocity: 2171.224423326793 km / s
# Optimal wind mass loss rate: 33.96223419892084 2.965e-09 solMass / yr
# Optimal wind final velocity: 2176.8682698310295 km / s
# Optimal wind mass loss rate: 33.99550630337445 2.965e-09 solMass / yr
# Optimal wind final velocity: 2172.357831014962 km / s
# Optimal wind mass loss rate: 33.984859866768176 2.965e-09 solMass / yr
# Optimal wind final velocity: 2174.306985769988 km / s
# Optimal wind mass loss rate: 34.00232504468377 2.965e-09 solMass / yr
# Optimal wind final velocity: 2170.3910261146243 km / s
# Optimal wind mass loss rate: 33.994359940297024 2.965e-09 solMass / yr
# Optimal wind final velocity: 2175.779340581647 km / s
# Optimal wind mass loss rate: 34.026370134855576 2.965e-09 solMass / yr
# Optimal wind final velocity: 2171.263262890672 km / s
# Optimal wind mass loss rate: 34.01560810609882 2.965e-09 solMass / yr
# Optimal wind final velocity: 2174.0335518886877 km / s
# Optimal wind mass loss rate: 34.03632312273031 2.965e-09 solMass / yr
# Optimal wind final velocity: 2170.090727678876 km / s
# Optimal wind mass loss rate: 34.028079326299085 2.965e-09 solMass / yr
# Optimal wind final velocity: 2174.9565906271155 km / s
# Optimal wind mass loss rate: 34.0576894404512 2.965e-09 solMass / yr
# Optimal wind final velocity: 2170.4403676428165 km / s
# Optimal wind mass loss rate: 34.04680246843807 2.965e-09 solMass / yr
# Optimal wind final velocity: 2172.0835845380657 km / s
# Optimal wind mass loss rate: 34.06261776298978 2.965e-09 solMass / yr
# Optimal wind final velocity: 2168.1482351515415 km / s
# Optimal wind mass loss rate: 34.05432716048102 2.965e-09 solMass / yr
# Optimal wind final velocity: 2173.9107851711287 km / s
# Optimal wind mass loss rate: 34.08741042776242 2.965e-09 solMass / yr
# Optimal wind final velocity: 2169.377230218316 km / s
# Optimal wind mass loss rate: 34.07639679647827 2.965e-09 solMass / yr
# Optimal wind final velocity: 2171.8681686281275 km / s
# Optimal wind mass loss rate: 34.09566271401438 2.965e-09 solMass / yr
# Optimal wind final velocity: 2167.917874025764 km / s
# Optimal wind mass loss rate: 34.08724012313825 2.965e-09 solMass / yr
# Optimal wind final velocity: 2173.049359604602 km / s
# Optimal wind mass loss rate: 34.117497470285066 2.965e-09 solMass / yr
# Optimal wind final velocity: 2168.5261565834267 km / s
# Optimal wind mass loss rate: 34.10649142761326 2.965e-09 solMass / yr
# Optimal wind final velocity: 2170.158654926253 km / s
# Optimal wind mass loss rate: 34.1219912000123 2.965e-09 solMass / yr
# Optimal wind final velocity: 2166.210453225148 km / s
# Optimal wind mass loss rate: 34.11353131046974 2.965e-09 solMass / yr
# Optimal wind final velocity: 2171.969483849364 km / s
# Optimal wind mass loss rate: 34.1463547975302 2.965e-09 solMass / yr
# Optimal wind final velocity: 2167.428414608247 km / s
# Optimal wind mass loss rate: 34.13525577690507 2.965e-09 solMass / yr
# Optimal wind final velocity: 2170.1826032373147 km / s
# Optimal wind mass loss rate: 34.155390519496294 2.965e-09 solMass / yr
# Optimal wind final velocity: 2166.2183921395376 km / s
# Optimal wind mass loss rate: 34.14681140382579 2.965e-09 solMass / yr
# Optimal wind final velocity: 2171.344639472563 km / s
# Optimal wind mass loss rate: 34.17678922785796 2.965e-09 solMass / yr
# Optimal wind final velocity: 2166.729643394025 km / s
# Optimal wind mass loss rate: 34.165339400541356 2.965e-09 solMass / yr
# Optimal wind final velocity: 2168.222746328846 km / s
# Optimal wind mass loss rate: 34.180096836121095 2.965e-09 solMass / yr
# Optimal wind final velocity: 2164.2712213096675 km / s
# Optimal wind mass loss rate: 34.17157629924412 2.965e-09 solMass / yr
# Optimal wind final velocity: 2170.03312971365 km / s
# Optimal wind mass loss rate: 34.204269210063586 2.965e-09 solMass / yr
# Optimal wind final velocity: 2165.4883339854177 km / s
# Optimal wind mass loss rate: 34.19314737009469 2.965e-09 solMass / yr
# Optimal wind final velocity: 2168.6672207850197 km / s
# Optimal wind mass loss rate: 34.21493212416394 2.965e-09 solMass / yr
# Optimal wind final velocity: 2164.1351845049126 km / s
# Optimal wind mass loss rate: 34.20387829662749 2.965e-09 solMass / yr
# Optimal wind final velocity: 2169.404813146126 km / s
# Optimal wind mass loss rate: 34.23432613234208 2.965e-09 solMass / yr
# Optimal wind final velocity: 2164.7953880600885 km / s
# Optimal wind mass loss rate: 34.22293511742886 2.965e-09 solMass / yr
# Optimal wind final velocity: 2166.4236330402814 km / s
# Optimal wind mass loss rate: 34.23818668056719 2.965e-09 solMass / yr
# Optimal wind final velocity: 2162.4655120524253 km / s
# Optimal wind mass loss rate: 34.2296378563871 2.965e-09 solMass / yr
# Optimal wind final velocity: 2168.0897279497512 km / s
# Optimal wind mass loss rate: 34.261627601405266 2.965e-09 solMass / yr
# Optimal wind final velocity: 2163.5429769148 km / s
# Optimal wind mass loss rate: 34.25055671421928 2.965e-09 solMass / yr
# Optimal wind final velocity: 2167.4242393300447 km / s
# Optimal wind mass loss rate: 34.27507315513114 2.965e-09 solMass / yr
# Optimal wind final velocity: 2162.8784229373937 km / s
# Optimal wind mass loss rate: 34.26402695671673 2.965e-09 solMass / yr
# Optimal wind final velocity: 2167.4632258839597 km / s
# Optimal wind mass loss rate: 34.29145146740976 2.965e-09 solMass / yr
# Optimal wind final velocity: 2162.857221718804 km / s
# Optimal wind mass loss rate: 34.280154490576265 2.965e-09 solMass / yr
# Optimal wind final velocity: 2165.6262502448208 km / s
# Optimal wind mass loss rate: 34.300137824714355 2.965e-09 solMass / yr
# Optimal wind final velocity: 2161.0830846031026 km / s
# Optimal wind mass loss rate: 34.28913847228355 2.965e-09 solMass / yr
# Optimal wind final velocity: 2166.363889074798 km / s
# Optimal wind mass loss rate: 34.31961778531698 2.965e-09 solMass / yr
# Optimal wind final velocity: 2161.8182425268515 km / s
# Optimal wind mass loss rate: 34.30864442043908 2.965e-09 solMass / yr
# Optimal wind final velocity: 2165.704127125001 km / s
# Optimal wind mass loss rate: 34.333134505296044 2.965e-09 solMass / yr
# Optimal wind final velocity: 2161.1601716044784 km / s
# Optimal wind mass loss rate: 34.32219498365711 2.965e-09 solMass / yr
# Optimal wind final velocity: 2165.3327238738507 km / s
# Optimal wind mass loss rate: 34.34788995639238 2.965e-09 solMass / yr
# Optimal wind final velocity: 2160.785491067389 km / s
# Optimal wind mass loss rate: 34.33696377468814 2.965e-09 solMass / yr
# Optimal wind final velocity: 2164.817002901539 km / s
# Optimal wind mass loss rate: 34.36205763070742 2.965e-09 solMass / yr
# Optimal wind final velocity: 2160.2732925597957 km / s
# Optimal wind mass loss rate: 34.351175245199265 2.965e-09 solMass / yr
# Optimal wind final velocity: 2164.4526866091683 km / s
# Optimal wind mass loss rate: 34.37692597994148 2.965e-09 solMass / yr
# Optimal wind final velocity: 2159.9070871222802 km / s
# Optimal wind mass loss rate: 34.36607680290782 2.965e-09 solMass / yr
# Optimal wind final velocity: 2163.9453319310805 km / s
# Optimal wind mass loss rate: 34.39121724939121 2.965e-09 solMass / yr
# Optimal wind final velocity: 2159.401575006115 km / s
# Optimal wind mass loss rate: 34.380397105405464 2.965e-09 solMass / yr
# Optimal wind final velocity: 2163.441213033708 km / s
# Optimal wind mass loss rate: 34.40555645550781 2.965e-09 solMass / yr
# Optimal wind final velocity: 2158.8986637735484 km / s
# Optimal wind mass loss rate: 34.39475966628222 2.965e-09 solMass / yr
# Optimal wind final velocity: 2162.942843162958 km / s
# Optimal wind mass loss rate: 34.41995411157107 2.965e-09 solMass / yr
# Optimal wind final velocity: 2158.4008848984313 km / s
# Optimal wind mass loss rate: 34.4091764008651 2.965e-09 solMass / yr
# Optimal wind final velocity: 2162.447628853339 km / s
# Optimal wind mass loss rate: 34.43439896942531 2.965e-09 solMass / yr
# Optimal wind final velocity: 2157.9055587877283 km / s
# Optimal wind mass loss rate: 34.42363679942127 2.965e-09 solMass / yr
# Optimal wind final velocity: 2162.0955256712928 km / s
# Optimal wind mass loss rate: 34.44946323169109 2.965e-09 solMass / yr
# Optimal wind final velocity: 2157.4807610495177 km / s
# Optimal wind mass loss rate: 34.43839557772188 2.965e-09 solMass / yr
# Optimal wind final velocity: 2161.53325744827 km / s
# Optimal wind mass loss rate: 34.463666479267424 2.965e-09 solMass / yr
# Optimal wind final velocity: 2156.990877862034 km / s
# Optimal wind mass loss rate: 34.452935568215835 2.965e-09 solMass / yr
# Optimal wind final velocity: 2161.1861197224302 km / s
# Optimal wind mass loss rate: 34.478798936646655 2.965e-09 solMass / yr
# Optimal wind final velocity: 2156.5713490210005 km / s
# Optimal wind mass loss rate: 34.46776240328047 2.965e-09 solMass / yr
# Optimal wind final velocity: 2160.6320662301678 km / s
# Optimal wind mass loss rate: 34.49311818399735 2.965e-09 solMass / yr
# Optimal wind final velocity: 2156.0189124861236 km / s
# Optimal wind mass loss rate: 34.482103308384985 2.965e-09 solMass / yr
# Optimal wind final velocity: 2160.2225599415265 km / s
# Optimal wind mass loss rate: 34.50804983800475 2.965e-09 solMass / yr
# Optimal wind final velocity: 2155.6071886350073 km / s
# Optimal wind mass loss rate: 34.497035476392774 2.965e-09 solMass / yr
# Optimal wind final velocity: 2159.8124179138 km / s
# Optimal wind mass loss rate: 34.522997582219965 2.965e-09 solMass / yr
# Optimal wind final velocity: 2155.1963204337185 km / s
# Optimal wind mass loss rate: 34.51199507696377 2.965e-09 solMass / yr
# Optimal wind final velocity: 2159.1185834508287 km / s
# Optimal wind mass loss rate: 34.53674396735498 2.965e-09 solMass / yr
# Optimal wind final velocity: 2154.504973945589 km / s
# Optimal wind mass loss rate: 34.52576703117494 2.965e-09 solMass / yr
# Optimal wind final velocity: 2158.9966322611863 km / s
# Optimal wind mass loss rate: 34.5529366257908 2.965e-09 solMass / yr
# Optimal wind final velocity: 2154.3818110994825 km / s
# Optimal wind mass loss rate: 34.54197109139026 2.965e-09 solMass / yr
# Optimal wind final velocity: 2158.1639338011855 km / s
# Optimal wind mass loss rate: 34.566104555515835 2.965e-09 solMass / yr
# Optimal wind final velocity: 2153.5494881293366 km / s
# Optimal wind mass loss rate: 34.555151650526945 2.965e-09 solMass / yr
# Optimal wind final velocity: 2158.046378669178 km / s
# Optimal wind mass loss rate: 34.582349432473045 2.965e-09 solMass / yr
# Optimal wind final velocity: 2153.4310380705697 km / s
# Optimal wind mass loss rate: 34.57140732571322 2.965e-09 solMass / yr
# Optimal wind final velocity: 2157.2180592308405 km / s
# Optimal wind mass loss rate: 34.595569673711324 2.965e-09 solMass / yr
# Optimal wind final velocity: 2152.603101960098 km / s
# Optimal wind mass loss rate: 34.58464129531656 2.965e-09 solMass / yr
# Optimal wind final velocity: 2157.1047862694354 km / s
# Optimal wind mass loss rate: 34.61186411811962 2.965e-09 solMass / yr
# Optimal wind final velocity: 2152.488207422547 km / s
# Optimal wind mass loss rate: 34.60093778033046 2.965e-09 solMass / yr
# Optimal wind final velocity: 2156.281396493153 km / s
# Optimal wind mass loss rate: 34.625159300067956 2.965e-09 solMass / yr
# Optimal wind final velocity: 2151.6654425179913 km / s
# Optimal wind mass loss rate: 34.61424972390547 2.965e-09 solMass / yr
# Optimal wind final velocity: 2156.0264173205987 km / s
# Optimal wind mass loss rate: 34.64084194671573 2.965e-09 solMass / yr
# Optimal wind final velocity: 2151.4076168501 km / s
# Optimal wind mass loss rate: 34.629928784466586 2.965e-09 solMass / yr
# Optimal wind final velocity: 2155.34536949353 km / s
# Optimal wind mass loss rate: 34.65474239707745 2.965e-09 solMass / yr
# Optimal wind final velocity: 2150.728774811514 km / s
# Optimal wind mass loss rate: 34.64384960873534 2.965e-09 solMass / yr
# Optimal wind final velocity: 2155.095415236996 km / s
# Optimal wind mass loss rate: 34.67047522154018 2.965e-09 solMass / yr
# Optimal wind final velocity: 2150.4754024016556 km / s
# Optimal wind mass loss rate: 34.65957830905284 2.965e-09 solMass / yr
# Optimal wind final velocity: 2154.416952367835 km / s
# Optimal wind mass loss rate: 34.68441082573189 2.965e-09 solMass / yr
# Optimal wind final velocity: 2149.798649890005 km / s
# Optimal wind mass loss rate: 34.67353138541838 2.965e-09 solMass / yr
# Optimal wind final velocity: 2154.1692751230285 km / s
# Optimal wind mass loss rate: 34.70016376765596 2.965e-09 solMass / yr
# Optimal wind final velocity: 2149.5461077258055 km / s
# Optimal wind mass loss rate: 34.68927541187206 2.965e-09 solMass / yr
# Optimal wind final velocity: 2153.491751127267 km / s
# Optimal wind mass loss rate: 34.71412107025592 2.965e-09 solMass / yr
# Optimal wind final velocity: 2148.872217489533 km / s
# Optimal wind mass loss rate: 34.703255934245064 2.965e-09 solMass / yr
# Optimal wind final velocity: 2153.246554809178 km / s
# Optimal wind mass loss rate: 34.72989007605444 2.965e-09 solMass / yr
# Optimal wind final velocity: 2148.622972883586 km / s
# Optimal wind mass loss rate: 34.71901639451974 2.965e-09 solMass / yr
# Optimal wind final velocity: 2152.428036832134 km / s
# Optimal wind mass loss rate: 34.74323956219776 2.965e-09 solMass / yr
# Optimal wind final velocity: 2147.808803181793 km / s
# Optimal wind mass loss rate: 34.732394498734166 2.965e-09 solMass / yr
# Optimal wind final velocity: 2152.325674178041 km / s
# Optimal wind mass loss rate: 34.75959136898975 2.965e-09 solMass / yr
# Optimal wind final velocity: 2147.7005683072584 km / s
# Optimal wind mass loss rate: 34.74872868295921 2.965e-09 solMass / yr
# Optimal wind final velocity: 2151.5095156942266 km / s
# Optimal wind mass loss rate: 34.77296455250907 2.965e-09 solMass / yr
# Optimal wind final velocity: 2146.887700006343 km / s
# Optimal wind mass loss rate: 34.76212425064732 2.965e-09 solMass / yr
# Optimal wind final velocity: 2151.408004373619 km / s
# Optimal wind mass loss rate: 34.789316280091086 2.965e-09 solMass / yr
# Optimal wind final velocity: 2146.781535534458 km / s
# Optimal wind mass loss rate: 34.778465756974654 2.965e-09 solMass / yr
# Optimal wind final velocity: 2150.5944288090172 km / s
# Optimal wind mass loss rate: 34.802715793843575 2.965e-09 solMass / yr
# Optimal wind final velocity: 2145.9709718879876 km / s
# Optimal wind mass loss rate: 34.79188822380884 2.965e-09 solMass / yr
# Optimal wind final velocity: 2150.49469573743 km / s
# Optimal wind mass loss rate: 34.819074665746946 2.965e-09 solMass / yr
# Optimal wind final velocity: 2145.8660438247757 km / s
# Optimal wind mass loss rate: 34.808233723557265 2.965e-09 solMass / yr
# Optimal wind final velocity: 2149.8220943519714 km / s
# Optimal wind mass loss rate: 34.83304662488638 2.965e-09 solMass / yr
# Optimal wind final velocity: 2145.197034213617 km / s
# Optimal wind mass loss rate: 34.82223123446502 2.965e-09 solMass / yr
# Optimal wind final velocity: 2149.3017132115465 km / s
# Optimal wind mass loss rate: 34.8476641753221 2.965e-09 solMass / yr
# Optimal wind final velocity: 2144.6760947506737 km / s
# Optimal wind mass loss rate: 34.836855837951674 2.965e-09 solMass / yr
# Optimal wind final velocity: 2149.0605545659414 km / s
# Optimal wind mass loss rate: 34.86342170606484 2.965e-09 solMass / yr
# Optimal wind final velocity: 2144.429696458064 km / s
# Optimal wind mass loss rate: 34.85260049678717 2.965e-09 solMass / yr
# Optimal wind final velocity: 2148.392576574394 km / s
# Optimal wind mass loss rate: 34.87741743264312 2.965e-09 solMass / yr
# Optimal wind final velocity: 2143.767076786377 km / s
# Optimal wind mass loss rate: 34.866628981444926 2.965e-09 solMass / yr
# Optimal wind final velocity: 2148.01698141383 km / s
# Optimal wind mass loss rate: 34.892623275609076 2.965e-09 solMass / yr
# Optimal wind final velocity: 2143.387871156667 km / s
# Optimal wind mass loss rate: 34.88182631066137 2.965e-09 solMass / yr
# Optimal wind final velocity: 2147.354812910612 km / s
# Optimal wind mass loss rate: 34.906643120065084 2.965e-09 solMass / yr
# Optimal wind final velocity: 2142.728018028151 km / s
# Optimal wind mass loss rate: 34.89586921581375 2.965e-09 solMass / yr
# Optimal wind final velocity: 2147.119245126726 km / s
# Optimal wind mass loss rate: 34.922424645999016 2.965e-09 solMass / yr
# Optimal wind final velocity: 2142.4885022442995 km / s
# Optimal wind mass loss rate: 34.911641296686106 2.965e-09 solMass / yr
# Optimal wind final velocity: 2146.459286182461 km / s
# Optimal wind mass loss rate: 34.9364591514513 2.965e-09 solMass / yr
# Optimal wind final velocity: 2141.830030730492 km / s
# Optimal wind mass loss rate: 34.925692853896365 2.965e-09 solMass / yr
# Optimal wind final velocity: 2146.225521044671 km / s
# Optimal wind mass loss rate: 34.95224779444667 2.965e-09 solMass / yr
# Optimal wind final velocity: 2141.593704601627 km / s
# Optimal wind mass loss rate: 34.94148107681594 2.965e-09 solMass / yr
# Optimal wind final velocity: 2145.5674483172043 km / s
# Optimal wind mass loss rate: 34.96629705146148 2.965e-09 solMass / yr
# Optimal wind final velocity: 2140.9366916714603 km / s
# Optimal wind mass loss rate: 34.95554591010636 2.965e-09 solMass / yr
# Optimal wind final velocity: 2145.335391717254 km / s
# Optimal wind mass loss rate: 34.98209618525202 2.965e-09 solMass / yr
# Optimal wind final velocity: 2140.7014393363766 km / s
# Optimal wind mass loss rate: 34.97134253038999 2.965e-09 solMass / yr
# Optimal wind final velocity: 2144.5334288046115 km / s
# Optimal wind mass loss rate: 34.99554772381773 2.965e-09 solMass / yr
# Optimal wind final velocity: 2139.9058920409598 km / s
# Optimal wind mass loss rate: 34.98483248406615 2.965e-09 solMass / yr
# Optimal wind final velocity: 2144.307410229134 km / s
# Optimal wind mass loss rate: 35.0113738196864 2.965e-09 solMass / yr
# Optimal wind final velocity: 2139.6741700973525 km / s
# Optimal wind mass loss rate: 35.0006460548082 2.965e-09 solMass / yr
# Optimal wind final velocity: 2143.794429454361 km / s
# Optimal wind mass loss rate: 35.02602045085991 2.965e-09 solMass / yr
# Optimal wind final velocity: 2139.162712581872 km / s
# Optimal wind mass loss rate: 35.01531055173019 2.965e-09 solMass / yr
# Optimal wind final velocity: 2143.4228324674873 km / s
# Optimal wind mass loss rate: 35.04124206590943 2.965e-09 solMass / yr
# Optimal wind final velocity: 2138.78780272607 km / s
# Optimal wind mass loss rate: 35.03053224057335 2.965e-09 solMass / yr
# Optimal wind final velocity: 2142.7662859678176 km / s
# Optimal wind mass loss rate: 35.05529357136249 2.965e-09 solMass / yr
# Optimal wind final velocity: 2138.1346391364596 km / s
# Optimal wind mass loss rate: 35.044608184121216 2.965e-09 solMass / yr
# Optimal wind final velocity: 2142.542428437329 km / s
# Optimal wind mass loss rate: 35.07113233541403 2.965e-09 solMass / yr
# Optimal wind final velocity: 2137.9034152301856 km / s
# Optimal wind mass loss rate: 35.06037588621568 2.965e-09 solMass / yr
# Optimal wind final velocity: 2141.885558775106 km / s
# Optimal wind mass loss rate: 35.08513932499936 2.965e-09 solMass / yr
# Optimal wind final velocity: 2137.2471675345737 km / s
# Optimal wind mass loss rate: 35.07438192057635 2.965e-09 solMass / yr
# Optimal wind final velocity: 2141.514716122663 km / s
# Optimal wind mass loss rate: 35.10030636114615 2.965e-09 solMass / yr
# Optimal wind final velocity: 2136.8765973271366 km / s
# Optimal wind mass loss rate: 35.089562347089625 2.965e-09 solMass / yr
# Optimal wind final velocity: 2141.144812184242 km / s
# Optimal wind mass loss rate: 35.11548002023155 2.965e-09 solMass / yr
# Optimal wind final velocity: 2136.503924842427 km / s
# Optimal wind mass loss rate: 35.10474366635859 2.965e-09 solMass / yr
# Optimal wind final velocity: 2140.487957573742 km / s
# Optimal wind mass loss rate: 35.12944143969 2.965e-09 solMass / yr
# Optimal wind final velocity: 2135.8509333404036 km / s
# Optimal wind mass loss rate: 35.11874186752536 2.965e-09 solMass / yr
# Optimal wind final velocity: 2140.2615359411257 km / s
# Optimal wind mass loss rate: 35.14513424781281 2.965e-09 solMass / yr
# Optimal wind final velocity: 2135.6209333978672 km / s
# Optimal wind mass loss rate: 35.13444125493876 2.965e-09 solMass / yr
# Optimal wind final velocity: 2139.4621824084193 km / s
# Optimal wind mass loss rate: 35.158507350511044 2.965e-09 solMass / yr
# Optimal wind final velocity: 2134.8280599770433 km / s
# Optimal wind mass loss rate: 35.1478642714548 2.965e-09 solMass / yr
# Optimal wind final velocity: 2139.384039088204 km / s
# Optimal wind mass loss rate: 35.174788656554206 2.965e-09 solMass / yr
# Optimal wind final velocity: 2134.7404863092556 km / s
# Optimal wind mass loss rate: 35.164128906483214 2.965e-09 solMass / yr
# Optimal wind final velocity: 2138.5863739134174 km / s
# Optimal wind mass loss rate: 35.188227057337045 2.965e-09 solMass / yr
# Optimal wind final velocity: 2133.951050975055 km / s
# Optimal wind mass loss rate: 35.17762474314219 2.965e-09 solMass / yr
# Optimal wind final velocity: 2138.5092650886436 km / s
# Optimal wind mass loss rate: 35.20452888284631 2.965e-09 solMass / yr
# Optimal wind final velocity: 2133.865710004345 km / s
# Optimal wind mass loss rate: 35.19391585287903 2.965e-09 solMass / yr
# Optimal wind final velocity: 2137.7150719193346 km / s
# Optimal wind mass loss rate: 35.21803180873858 2.965e-09 solMass / yr
# Optimal wind final velocity: 2133.079789283776 km / s
# Optimal wind mass loss rate: 35.20747551286727 2.965e-09 solMass / yr
# Optimal wind final velocity: 2137.64216149408 km / s
# Optimal wind mass loss rate: 35.234395306919 2.965e-09 solMass / yr
# Optimal wind final velocity: 2133.0005945161365 km / s
# Optimal wind mass loss rate: 35.22384575388219 2.965e-09 solMass / yr
# Optimal wind final velocity: 2136.7091021278543 km / s
# Optimal wind mass loss rate: 35.247386676894166 2.965e-09 solMass / yr
# Optimal wind final velocity: 2132.075386140968 km / s
# Optimal wind mass loss rate: 35.23688142486384 2.965e-09 solMass / yr
# Optimal wind final velocity: 2136.7862525031405 km / s
# Optimal wind mass loss rate: 35.264388319196314 2.965e-09 solMass / yr
# Optimal wind final velocity: 2132.144342030412 km / s
# Optimal wind mass loss rate: 35.25387891911058 2.965e-09 solMass / yr
# Optimal wind final velocity: 2135.710133218756 km / s
# Optimal wind mass loss rate: 35.276835039254 2.965e-09 solMass / yr
# Optimal wind final velocity: 2131.0744260233278 km / s
# Optimal wind mass loss rate: 35.26637316211132 2.965e-09 solMass / yr
# Optimal wind final velocity: 2135.7898197006407 km / s
# Optimal wind mass loss rate: 35.29389873654957 2.965e-09 solMass / yr
# Optimal wind final velocity: 2131.1484301834766 km / s
# Optimal wind mass loss rate: 35.28343125330019 2.965e-09 solMass / yr
# Optimal wind final velocity: 2134.8656920343788 km / s
# Optimal wind mass loss rate: 35.30702040872346 2.965e-09 solMass / yr
# Optimal wind final velocity: 2130.229826618495 km / s
# Optimal wind mass loss rate: 35.29659666445881 2.965e-09 solMass / yr
# Optimal wind final velocity: 2134.950304727124 km / s
# Optimal wind mass loss rate: 35.32414474171165 2.965e-09 solMass / yr
# Optimal wind final velocity: 2130.308143555436 km / s
# Optimal wind mass loss rate: 35.313711567740135 2.965e-09 solMass / yr
# Optimal wind final velocity: 2133.8828782182677 km / s
# Optimal wind mass loss rate: 35.336719951298015 2.965e-09 solMass / yr
# Optimal wind final velocity: 2129.2468564443175 km / s
# Optimal wind mass loss rate: 35.326332430669645 2.965e-09 solMass / yr
# Optimal wind final velocity: 2133.9717568724423 km / s
# Optimal wind mass loss rate: 35.35389688764393 2.965e-09 solMass / yr
# Optimal wind final velocity: 2129.3296684775564 km / s
# Optimal wind mass loss rate: 35.34350493280329 2.965e-09 solMass / yr
# Optimal wind final velocity: 2133.053783589589 km / s
# Optimal wind mass loss rate: 35.36710523377339 2.965e-09 solMass / yr
# Optimal wind final velocity: 2128.417017592812 km / s
# Optimal wind mass loss rate: 35.35674874792836 2.965e-09 solMass / yr
# Optimal wind final velocity: 2133.1468112444027 km / s
# Optimal wind mass loss rate: 35.384336204547154 2.965e-09 solMass / yr
# Optimal wind final velocity: 2128.504043267095 km / s
# Optimal wind mass loss rate: 35.37397671675842 2.965e-09 solMass / yr
# Optimal wind final velocity: 2131.941116608675 km / s
# Optimal wind mass loss rate: 35.396420077136106 2.965e-09 solMass / yr
# Optimal wind final velocity: 2127.3171220235467 km / s
# Optimal wind mass loss rate: 35.386149049996554 2.965e-09 solMass / yr
# Optimal wind final velocity: 2132.2006782569524 km / s
# Optimal wind mass loss rate: 35.41431239736079 2.965e-09 solMass / yr
# Optimal wind final velocity: 2127.5580990265917 km / s
# Optimal wind mass loss rate: 35.40398761912552 2.965e-09 solMass / yr
# Optimal wind final velocity: 2131.1435350325105 km / s
# Optimal wind mass loss rate: 35.42702112337133 2.965e-09 solMass / yr
# Optimal wind final velocity: 2126.5064895467417 km / s
# Optimal wind mass loss rate: 35.416733096424316 2.965e-09 solMass / yr
# Optimal wind final velocity: 2131.3851835232967 km / s
# Optimal wind mass loss rate: 35.44484597474915 2.965e-09 solMass / yr
# Optimal wind final velocity: 2126.7440421575748 km / s
# Optimal wind mass loss rate: 35.43455795535139 2.965e-09 solMass / yr
# Optimal wind final velocity: 2129.692240302858 km / s
# Optimal wind mass loss rate: 35.45501343529164 2.965e-09 solMass / yr
# Optimal wind final velocity: 2125.0541243708494 km / s
# Optimal wind mass loss rate: 35.44475152127107 2.965e-09 solMass / yr
# Optimal wind final velocity: 2130.4883460138785 km / s
# Optimal wind mass loss rate: 35.47504337999102 2.965e-09 solMass / yr
# Optimal wind final velocity: 2125.8466738487587 km / s
# Optimal wind mass loss rate: 35.46478494334172 2.965e-09 solMass / yr
# Optimal wind final velocity: 2128.6551882352883 km / s
# Optimal wind mass loss rate: 35.484666016914716 2.965e-09 solMass / yr
# Optimal wind final velocity: 2124.01903766579 km / s
# Optimal wind mass loss rate: 35.47444258758343 2.965e-09 solMass / yr
# Optimal wind final velocity: 2129.4621299224505 km / s
# Optimal wind mass loss rate: 35.50476330353747 2.965e-09 solMass / yr
# Optimal wind final velocity: 2124.8176516835783 km / s
# Optimal wind mass loss rate: 35.49452248929602 2.965e-09 solMass / yr
# Optimal wind final velocity: 2128.8371141102853 km / s
# Optimal wind mass loss rate: 35.51919128240055 2.965e-09 solMass / yr
# Optimal wind final velocity: 2124.193281380526 km / s
# Optimal wind mass loss rate: 35.50896766245768 2.965e-09 solMass / yr
# Optimal wind final velocity: 2128.508225839944 km / s
# Optimal wind mass loss rate: 35.534825946799465 2.965e-09 solMass / yr
# Optimal wind final velocity: 2123.8632665400237 km / s
# Optimal wind mass loss rate: 35.524612969781884 2.965e-09 solMass / yr
# Optimal wind final velocity: 2128.0331004862423 km / s
# Optimal wind mass loss rate: 35.549879001375 2.965e-09 solMass / yr
# Optimal wind final velocity: 2123.387699514899 km / s
# Optimal wind mass loss rate: 35.53967817590141 2.965e-09 solMass / yr
# Optimal wind final velocity: 2127.5593584760813 km / s
# Optimal wind mass loss rate: 35.56494682219674 2.965e-09 solMass / yr
# Optimal wind final velocity: 2122.9140475103204 km / s
# Optimal wind mass loss rate: 35.55475975762245 2.965e-09 solMass / yr
# Optimal wind final velocity: 2127.0881791737634 km / s
# Optimal wind mass loss rate: 35.58003162784421 2.965e-09 solMass / yr
# Optimal wind final velocity: 2122.441257344826 km / s
# Optimal wind mass loss rate: 35.56985139402745 2.965e-09 solMass / yr
# Optimal wind final velocity: 2126.6167871891107 km / s
# Optimal wind mass loss rate: 35.595119547150794 2.965e-09 solMass / yr
# Optimal wind final velocity: 2121.969818364034 km / s
# Optimal wind mass loss rate: 35.584952263236715 2.965e-09 solMass / yr
# Optimal wind final velocity: 2126.147299418877 km / s
# ...
# Optimal wind mass loss rate: 39.964156754685824 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.6379616739978 km / s
# Optimal wind mass loss rate: 39.99897366498719 2.965e-09 solMass / yr
# Optimal wind final velocity: 1992.2207018280153 km / s
# Optimal wind mass loss rate: 39.963919761071594 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.6236382116347 km / s
# Optimal wind mass loss rate: 39.99873589019734 2.965e-09 solMass / yr
# Optimal wind final velocity: 1992.228530856373 km / s
# Optimal wind mass loss rate: 39.965515273797514 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.6323568916687 km / s
# Optimal wind mass loss rate: 40.00033468726415 2.965e-09 solMass / yr
# Optimal wind final velocity: 1992.2148918680036 km / s
# Optimal wind mass loss rate: 39.965281924932185 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.6186035602775 km / s
# Optimal wind mass loss rate: 40.000100488482616 2.965e-09 solMass / yr
# Optimal wind final velocity: 1992.2012247734879 km / s
# Optimal wind mass loss rate: 39.965048105067055 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.6042015084026 km / s
# Optimal wind mass loss rate: 39.9998641790674 2.965e-09 solMass / yr
# Optimal wind final velocity: 1992.1869389305434 km / s
# Optimal wind mass loss rate: 39.964812251250315 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.589944492245 km / s
# Optimal wind mass loss rate: 39.99962653433377 2.965e-09 solMass / yr
# Optimal wind final velocity: 1992.1729796317352 km / s
# Optimal wind mass loss rate: 39.96457521535497 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.574146343046 km / s
# Optimal wind mass loss rate: 39.99938421999281 2.965e-09 solMass / yr
# Optimal wind final velocity: 1992.1575477496604 km / s
# Optimal wind mass loss rate: 39.96433392672026 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.5586426697046 km / s
# Optimal wind mass loss rate: 39.999142548535865 2.965e-09 solMass / yr
# Optimal wind final velocity: 1992.1422173385217 km / s
# Optimal wind mass loss rate: 39.964091655503644 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.5434601719116 km / s
# Optimal wind mass loss rate: 39.99890298555411 2.965e-09 solMass / yr
# Optimal wind final velocity: 1992.1492734820347 km / s
# Optimal wind mass loss rate: 39.96568634282471 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.550638774536 km / s
# Optimal wind mass loss rate: 40.000495661202145 2.965e-09 solMass / yr
# Optimal wind final velocity: 1992.1339703128278 km / s
# Optimal wind mass loss rate: 39.965447129515475 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.5351521977466 km / s
# Optimal wind mass loss rate: 40.000254047821144 2.965e-09 solMass / yr
# Optimal wind final velocity: 1992.1187317029803 km / s
# Optimal wind mass loss rate: 39.9652063538822 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.519828838466 km / s
# Optimal wind mass loss rate: 40.00001282905244 2.965e-09 solMass / yr
# Optimal wind final velocity: 1992.1034505432813 km / s
# Optimal wind mass loss rate: 39.96496496572147 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.5046695589124 km / s
# Optimal wind mass loss rate: 39.9997725796834 2.965e-09 solMass / yr
# Optimal wind final velocity: 1992.0885014410853 km / s
# Optimal wind mass loss rate: 39.96472521661586 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.4896553856865 km / s
# Optimal wind mass loss rate: 39.99953256091735 2.965e-09 solMass / yr
# Optimal wind final velocity: 1992.0736959113106 km / s
# Optimal wind mass loss rate: 39.96448471555664 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.4752112278923 km / s
# Optimal wind mass loss rate: 39.999295476407134 2.965e-09 solMass / yr
# Optimal wind final velocity: 1992.0593788380716 km / s
# Optimal wind mass loss rate: 39.964248097363004 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.4609192947566 km / s
# Optimal wind mass loss rate: 39.99905869131175 2.965e-09 solMass / yr
# Optimal wind final velocity: 1992.0676825069224 km / s
# Optimal wind mass loss rate: 39.965846504816774 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.4689159208638 km / s
# Optimal wind mass loss rate: 40.000652061476174 2.965e-09 solMass / yr
# Optimal wind final velocity: 1992.052637309986 km / s
# Optimal wind mass loss rate: 39.965605900947736 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.454092929243 km / s
# Optimal wind mass loss rate: 40.00041300964177 2.965e-09 solMass / yr
# Optimal wind final velocity: 1992.038227597344 km / s
# Optimal wind mass loss rate: 39.965368296500465 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.4397169541894 km / s
# Optimal wind mass loss rate: 40.00017538194612 2.965e-09 solMass / yr
# Optimal wind final velocity: 1992.0238672800876 km / s
# Optimal wind mass loss rate: 39.9651293826517 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.425499328694 km / s
# Optimal wind mass loss rate: 39.99993922023948 2.965e-09 solMass / yr
# Optimal wind final velocity: 1992.0107117526695 km / s
# Optimal wind mass loss rate: 39.96489671225649 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.4122751834263 km / s
# Optimal wind mass loss rate: 39.99970611246469 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.9974785716986 km / s
# Optimal wind mass loss rate: 39.96466360363 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.3988876805156 km / s
# Optimal wind mass loss rate: 39.99947238226275 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.98258265404 km / s
# Optimal wind mass loss rate: 39.96442229900208 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.3838815223753 km / s
# Optimal wind mass loss rate: 39.99923093308987 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.9907362765425 km / s
# Optimal wind mass loss rate: 39.96602090572262 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.3922709341946 km / s
# Optimal wind mass loss rate: 40.00082689164087 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.9774414434899 km / s
# Optimal wind mass loss rate: 39.965787031768386 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.3789332486824 km / s
# Optimal wind mass loss rate: 40.00059276462831 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.9640526978033 km / s
# Optimal wind mass loss rate: 39.965551220909994 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.365501057832 km / s
# Optimal wind mass loss rate: 40.00035909198035 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.9493390335904 km / s
# Optimal wind mass loss rate: 39.965313332046854 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.3506106542304 km / s
# Optimal wind mass loss rate: 40.00012040438796 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.9345215301892 km / s
# Optimal wind mass loss rate: 39.96507495455214 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.3351977290672 km / s
# Optimal wind mass loss rate: 39.99987996300904 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.9191732332574 km / s
# Optimal wind mass loss rate: 39.96483223166113 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.3204099497086 km / s
# Optimal wind mass loss rate: 39.99963948725247 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.9041519685386 km / s
# Optimal wind mass loss rate: 39.96459226586486 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.3053845208394 km / s
# Optimal wind mass loss rate: 39.99939967529302 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.9122280140366 km / s
# Optimal wind mass loss rate: 39.966191149834316 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.3132047336599 km / s
# Optimal wind mass loss rate: 40.00099607947491 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.8972228922232 km / s
# Optimal wind mass loss rate: 39.96595233646748 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.298843244694 km / s
# Optimal wind mass loss rate: 40.00075920157022 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.882793945798 km / s
# Optimal wind mass loss rate: 39.965715279976514 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.284112037942 km / s
# Optimal wind mass loss rate: 40.00052097586142 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.8676811802425 km / s
# Optimal wind mass loss rate: 39.965473184811415 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.2680779029836 km / s
# Optimal wind mass loss rate: 40.00027600817665 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.8520671972394 km / s
# Optimal wind mass loss rate: 39.965229774122236 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.2524160776484 km / s
# Optimal wind mass loss rate: 40.000032602174684 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.8366225706159 km / s
# Optimal wind mass loss rate: 39.96498888466362 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.2369466673204 km / s
# Optimal wind mass loss rate: 39.99979178941689 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.8210594324844 km / s
# Optimal wind mass loss rate: 39.96474788824138 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.221262707616 km / s
# Optimal wind mass loss rate: 39.999550177764156 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.8285177174719 km / s
# Optimal wind mass loss rate: 39.96634436236011 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.2289814439137 km / s
# Optimal wind mass loss rate: 40.00114585889785 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.8131354326515 km / s
# Optimal wind mass loss rate: 39.96610410928153 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.2135481027478 km / s
# Optimal wind mass loss rate: 40.000905332541706 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.7973724880694 km / s
# Optimal wind mass loss rate: 39.965859974703925 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.1977263132726 km / s
# Optimal wind mass loss rate: 40.00066139056263 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.7818588416148 km / s
# Optimal wind mass loss rate: 39.96561869599608 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.182137209007 km / s
# Optimal wind mass loss rate: 40.000420021112234 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.7663605740331 km / s
# Optimal wind mass loss rate: 39.965377807792485 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.1667906337382 km / s
# Optimal wind mass loss rate: 40.00017945350652 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.7508774134974 km / s
# Optimal wind mass loss rate: 39.96513696016364 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.1513814480165 km / s
# Optimal wind mass loss rate: 39.99993875912016 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.7354118687272 km / s
# Optimal wind mass loss rate: 39.964895960499774 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.1359344026553 km / s
# Optimal wind mass loss rate: 39.999697727135384 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.7430957334761 km / s
# Optimal wind mass loss rate: 39.96649312427832 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.14345684973 km / s
# Optimal wind mass loss rate: 40.001292909371635 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.727325125126 km / s
# Optimal wind mass loss rate: 39.9662495140515 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.127979675153 km / s
# Optimal wind mass loss rate: 40.001050437324665 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.7118652941524 km / s
# Optimal wind mass loss rate: 39.966008569223376 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.112541469447 km / s
# Optimal wind mass loss rate: 40.000809603881244 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.6965568084645 km / s
# Optimal wind mass loss rate: 39.96576828347292 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.0972365969792 km / s
# Optimal wind mass loss rate: 40.00056923693902 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.6819245980273 km / s
# Optimal wind mass loss rate: 39.965530058159466 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.0809983749923 km / s
# Optimal wind mass loss rate: 40.000325625140746 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.6658421821642 km / s
# Optimal wind mass loss rate: 39.9652870510307 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.064474179621 km / s
# Optimal wind mass loss rate: 40.00008105240141 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.6495209919171 km / s
# Optimal wind mass loss rate: 39.96504323448504 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.0484678863627 km / s
# Optimal wind mass loss rate: 39.99983870014413 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.6567810547347 km / s
# Optimal wind mass loss rate: 39.96663941622675 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.0559882341238 km / s
# Optimal wind mass loss rate: 40.001433910312045 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.6406998913656 km / s
# Optimal wind mass loss rate: 39.96639634455658 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.0397498190061 km / s
# Optimal wind mass loss rate: 40.00119046188731 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.6246648448962 km / s
# Optimal wind mass loss rate: 39.96615366681125 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.0234179667455 km / s
# Optimal wind mass loss rate: 40.00094671322138 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.608373379488 km / s
# Optimal wind mass loss rate: 39.96590994133537 2.965e-09 solMass / yr
# Optimal wind final velocity: 2000.0034025663635 km / s
# Optimal wind mass loss rate: 40.00069052884477 2.965e-09 solMass / yr
# Optimal wind final velocity: 1991.5881409418882 km / s
# Optimal wind mass loss rate: 39.965653133786404 2.965e-09 solMass / yr
# Optimal wind final velocity: 1999.9867489295173 km / s
# Optimal wind mass loss rate: 40.000445377225304 2.965e-09 solMass / yr
# Optimal wind final velocity: 2005.2965313134264 km / s
# Optimal wind mass loss rate: 40.01059943722899 2.965e-09 solMass / yr
# Optimal wind final velocity: 1996.8773746110787 km / s
# Optimal wind mass loss rate: 39.97549748948488 2.965e-09 solMass / yr
# Optimal wind final velocity: 2005.285922984304 km / s
# Optimal wind mass loss rate: 40.01040589897843 2.965e-09 solMass / yr
# Optimal wind final velocity: 1996.8665801035306 km / s
# Optimal wind mass loss rate: 39.9753011917147 2.965e-09 solMass / yr
# Optimal wind final velocity: 2005.2750024504405 km / s
# Optimal wind mass loss rate: 40.01020928574789 2.965e-09 solMass / yr
# Optimal wind final velocity: 1996.8557283485384 km / s
# Optimal wind mass loss rate: 39.97510487614138 2.965e-09 solMass / yr
# Optimal wind final velocity: 2005.264152896362 km / s
# Optimal wind mass loss rate: 40.010012957534 2.965e-09 solMass / yr
# Optimal wind final velocity: 1996.8448626675065 km / s
# Optimal wind mass loss rate: 39.97490851838728 2.965e-09 solMass / yr
# Optimal wind final velocity: 2005.2532665444378 km / s
# Optimal wind mass loss rate: 40.00981650804361 2.965e-09 solMass / yr
# Optimal wind final velocity: 1996.8344181622028 km / s
# Optimal wind mass loss rate: 39.974714383824185 2.965e-09 solMass / yr
# Optimal wind final velocity: 2005.242718184511 km / s
# Optimal wind mass loss rate: 40.009621910378684 2.965e-09 solMass / yr
# Optimal wind final velocity: 1996.823962989721 km / s
# Optimal wind mass loss rate: 39.97452013379593 2.965e-09 solMass / yr
# Optimal wind final velocity: 2005.2321817829852 km / s
# Optimal wind mass loss rate: 40.00942736963546 2.965e-09 solMass / yr
# Optimal wind final velocity: 1996.8135950371852 km / s
# Optimal wind mass loss rate: 39.974326181606955 2.965e-09 solMass / yr
# Optimal wind final velocity: 2005.221597498012 km / s
# Optimal wind mass loss rate: 40.00923255817336 2.965e-09 solMass / yr
# Optimal wind final velocity: 1996.8031397847053 km / s
# Optimal wind mass loss rate: 39.97413168885659 2.965e-09 solMass / yr

# %% [markdown]
# ## Loss map plot

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
from matplotlib.colors import LogNorm
from mpl_toolkits.axes_grid1 import make_axes_locatable

divider = make_axes_locatable(axs[0])
cax = divider.append_axes('right', size='5%', pad=0.05)
norm = LogNorm(vmin=loss_map.min(), vmax=loss_map.max())
mapper = plt.cm.ScalarMappable(norm=norm, cmap=plt.cm.viridis)
plt.colorbar(mapper, cax=cax, orientation='vertical', label='primitive state loss')

# plot as heatmap
# axs[0].imshow(loss_map, origin='lower', extent=[
#     (velocities[0] * code_units.code_velocity).to(u.km / u.s).value,
#     (velocities[-1] * code_units.code_velocity).to(u.km / u.s).value,
#     (mass_loss_rates[0] * code_units.code_mass / code_units.code_time).to(2.965e-3 / (1e6 * u.yr) * u.M_sun).value,
#     (mass_loss_rates[-1] * code_units.code_mass / code_units.code_time).to(2.965e-3 / (1e6 * u.yr) * u.M_sun).value
# ], aspect='auto', norm=norm)

axs[0].scatter((vel_list * code_units.code_velocity).to(u.km / u.s).value, (mass_list * code_units.code_mass / code_units.code_time).to(2.965e-3 / (1e6 * u.yr) * u.M_sun).value, c=loss_map, cmap='viridis', norm=norm, s = 15, marker = "s")

axs[0].set_xlabel('Final Wind Velocity in km/s')
axs[0].set_ylabel('Mass of the Star in M_sun')
axs[0].set_title('loss landscape')

# plot the loss function
axs[1].plot(loss_list1, label='loss 1', color='blue')

# plot the optimization path
xlist1 = jnp.array(xlist1)
axs[0].plot((xlist1[:, 0] * code_units.code_velocity).to(u.km / u.s).value, (xlist1[:, 1] * code_units.code_mass / code_units.code_time).to(2.965e-3 / (1e6 * u.yr) * u.M_sun).value, color='blue', label='optimization path 1')
axs[0].scatter(
    [(xlist1[0, 0] * code_units.code_velocity).to(u.km / u.s).value], [(xlist1[0, 1] * code_units.code_mass / code_units.code_time).to(2.965e-3 / (1e6 * u.yr) * u.M_sun).value],
    c='blue', s = 40
)


# plot the optimization path
xlist2 = jnp.array(xlist2)
axs[0].plot((xlist2[:, 0] * code_units.code_velocity).to(u.km / u.s).value, (xlist2[:, 1] * code_units.code_mass / code_units.code_time).to(2.965e-3 / (1e6 * u.yr) * u.M_sun).value, color='purple', label='optimization path 2')

axs[0].scatter(
    [(xlist2[0, 0] * code_units.code_velocity).to(u.km / u.s).value], [(xlist2[0, 1] * code_units.code_mass / code_units.code_time).to(2.965e-3 / (1e6 * u.yr) * u.M_sun).value],
    c='purple', s = 40
)
    

# plot the loss function
axs[1].plot(loss_list2, label='loss 2', color='purple')

# plot the optimization path
xlist3 = jnp.array(xlist3)
axs[0].plot((xlist3[:, 0] * code_units.code_velocity).to(u.km / u.s).value, (xlist3[:, 1] * code_units.code_mass / code_units.code_time).to(2.965e-3 / (1e6 * u.yr) * u.M_sun).value, color='red', label='optimization path 3')

axs[0].scatter(
    [(xlist3[0, 0] * code_units.code_velocity).to(u.km / u.s).value], [(xlist3[0, 1] * code_units.code_mass / code_units.code_time).to(2.965e-3 / (1e6 * u.yr) * u.M_sun).value],
    c='red', s = 40
)



# plot the loss function
axs[1].plot(loss_list3, label='loss 3', color='red')


axs[1].set_xlabel('iterations')
axs[1].set_ylabel('primitive state loss')
axs[1].set_title('primitive state loss convergence')
# log y
axs[1].set_yscale('log')
# top right legend
axs[1].legend(loc='upper right')
plt.tight_layout()

# mark the true value as a red dot
axs[0].scatter(
    [wind_final_velocity.to(u.km / u.s).value],
    [wind_mass_loss_rate.to(2.965e-3 / (1e6 * u.yr) * u.M_sun).value],
    c='white', s = 200, label='true wind parameters', marker = "*", zorder = 10, edgecolors='black'
)


axs[0].legend()
axs[1].legend()

# axs 1 y lim 10^6 to 3 * 10^9
axs[1].set_ylim(1e6, 3e9)

print(full_profile_loss(((2000 * u.km / u.s).to(code_units.code_velocity).value, (2.965e-3 / (1e6 * u.yr) * 40 * u.M_sun).to(code_units.code_mass / code_units.code_time).value)))

plt.savefig('optimization.png')
# Out:
# 0.0
